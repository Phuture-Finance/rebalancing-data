# %% [markdown]
# ## CAI - Colony Avalanche Index - Rebalancing data for July 2024

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import decouple
import sys
sys.path.append('../')
from methodology import MethodologyProd
from pycoingecko import CoinGeckoAPI
key =  decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key=key)

# %% [markdown]
# ## Index Variables

# %%
date = '2024-07-01'
min_mcap =  0.1e8
min_weight = 0.005
max_weight = 0.5
circ_supply_threshold = 0.3
liveness_threshold = 180 # In days
liquidity_consistency = 90 # In days
coingecko_category = ["avalanche-ecosystem"]

# Calculating max slippage based on liquidity threshold
liq = 2*1e6
liq_os = liq / 2 # one-side liquidity 
trade_value_tiny = 1e2
trade_value = 1e5
max_slippage = (liq_os + trade_value_tiny) / (liq_os + trade_value) - 1
# round to the nearest .01
max_slippage = round(max_slippage, 2)

# Dataframes to remove
stablecoins = pd.DataFrame(cg.get_coins_markets('usd',category='stablecoins')).set_index('id')
ctokens = pd.DataFrame(cg.get_coins_markets('usd',category='compound-tokens')).set_index('id')
atokens = pd.DataFrame(cg.get_coins_markets('usd',category='aave-tokens')).set_index('id')

methodology_class = MethodologyProd(
                                date,
                                1,
                                "avalanche",
                                "0x48f88A3fE843ccb0b5003e70B4192c1d7448bEf0",
                                "cai_benchmark_data",
                                "cai_liquidities",
                                min_mcap,
                                min_weight,
                                max_weight,
                                100000,
                                255,
                                circ_supply_threshold,
                                liveness_threshold,
                                liquidity_consistency,
                                -0.12,
                                coingecko_category)

# %% [markdown]
# ## Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data at least 6 months prior to the date of inclusion in the index.
#     1. The project should have a token that is native to Avalanche. This excludes wrapped variants, where the underlying tokens are locked on an alt-L1.
#     1. The project should be a going concern, with a dedicated team actively building, supporting and maintaining the project.
#     1. No rebasing or deflationary tokens.
#     1. The project must be widely considered to be building a useful protocol or product. Projects that have ponzi characteristics at the core of their offering will not be considered.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project’s protocol or product must have significant usage.
#     <br>
# 1. **Pricing requirements**
#     1. Token should have a Chainlink price feed to allow for manipulation resistant pricing.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 30% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The token should have in aggregate at least $2mm of onchain liquidity across Trader Joe, Platypus, Pangolin.
#     1. The token must have shown consistent DeFi liquidity on Avalanche.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.

# %% [markdown]
# ## Run Methodology

# %%
results,liquidity = methodology_class.main(
    single_chain="avalanche",
    df_to_remove=[stablecoins,ctokens,atokens],
    ids_to_replace=[["avalanche-2"],["benqi-liquid-staked-avax"]],
    add_category_assets=["shrapnel-2"],
    remove_category_assets=['wrapped-bitcoin',"gmx","euro-coin","bitcoin-avalanche-bridged-btc-b","benqi-liquid-staked-avax","pangolin"],
    values_to_update=[{'id':'pangolin','category':'total_supply','value':230000000},
                      {'id':'benqi-liquid-staked-avax','category':'market_cap','value':20000000000},
                      {'id':'benqi-liquid-staked-avax','category':'symbol','value':"sAVAX"}
                      ],
    enable_liquidity_score=True

    )
liquidity
# Out:
# Excluding ox-fun, pricing data available only for 136 < 180 days
# Excluding platypus-usd, pricing data available only for 13 < 180 days
# Table created successfully
# Table created successfully
# Manually calculating slippage for benqi-liquid-staked-avax on avalanche
# Manually calculating slippage for chainlink on avalanche
# Manually calculating slippage for uniswap on avalanche
# Manually calculating slippage for maker on avalanche
# Manually calculating slippage for the-graph on avalanche
# Manually calculating slippage for aave on avalanche
# havven on avalanche returned an invalid API response
# havven recorded no valid response across any platform
# Manually calculating slippage for 1inch on avalanche
# axelar on avalanche returned an invalid API response
# axelar recorded no valid response across any platform
# Manually calculating slippage for woo-network on avalanche
# Manually calculating slippage for compound-governance-token on avalanche
# ankr on avalanche returned an invalid API response
# ankr recorded no valid response across any platform
# Manually calculating slippage for 0x on avalanche
# Manually calculating slippage for basic-attention-token on avalanche
# Manually calculating slippage for frax-share on avalanche
# Manually calculating slippage for yearn-finance on avalanche
# Manually calculating slippage for osaka-protocol on avalanche
# osaka-protocol on avalanche returned an invalid API response
# osaka-protocol recorded no valid response across any platform
# Manually calculating slippage for uma on avalanche
# Manually calculating slippage for ampleforth on avalanche
# Manually calculating slippage for balancer on avalanche
# Manually calculating slippage for sushi on avalanche
# Manually calculating slippage for insure on avalanche
# cartesi on avalanche returned an invalid API response
# cartesi recorded no valid response across any platform
# Manually calculating slippage for synapse-2 on avalanche
# Manually calculating slippage for joe on avalanche
# Manually calculating slippage for coq-inu on avalanche
# Manually calculating slippage for orbs on avalanche
# Manually calculating slippage for spell-token on avalanche
# Manually calculating slippage for kyber-network-crystal on avalanche
# kyber-network-crystal on avalanche returned an invalid API response
# kyber-network-crystal recorded no valid response across any platform
# telos on avalanche returned an invalid API response
# telos recorded no valid response across any platform
# Manually calculating slippage for beta-finance on avalanche
# Manually calculating slippage for alpha-finance on avalanche
# Manually calculating slippage for benqi on avalanche
# allianceblock-nexera on avalanche returned an invalid API response
# allianceblock-nexera recorded no valid response across any platform
# ankreth on avalanche returned an invalid API response
# ankreth recorded no valid response across any platform
# route on avalanche returned an invalid API response
# route recorded no valid response across any platform
# Manually calculating slippage for aleph on avalanche
# Manually calculating slippage for meld-2 on avalanche
# Manually calculating slippage for deapcoin on avalanche
# miracle-play on avalanche returned an invalid API response
# miracle-play recorded no valid response across any platform
# Manually calculating slippage for snowbank on avalanche
# Manually calculating slippage for dexalot on avalanche
# Manually calculating slippage for baklava on avalanche
# idia on avalanche returned an invalid API response
# idia recorded no valid response across any platform
# Manually calculating slippage for gamer-arena on avalanche
# Manually calculating slippage for avalaunch on avalanche
# Manually calculating slippage for gogopool-ggavax on avalanche
# Manually calculating slippage for raini-studios-token on avalanche
# Manually calculating slippage for defi-kingdoms on avalanche
# Manually calculating slippage for xen-crypto on avalanche
# xen-crypto on avalanche returned an invalid API response
# xen-crypto recorded no valid response across any platform
# Manually calculating slippage for playa3ull-games-2 on avalanche
# Manually calculating slippage for trustswap on avalanche
# Manually calculating slippage for xana on avalanche
# Manually calculating slippage for colony on avalanche
# Manually calculating slippage for dextf on avalanche
# Manually calculating slippage for ferrum-network on avalanche
# Manually calculating slippage for step-app-fitfi on avalanche
# pangolin did not meet the average three month liquidity threshold
# chainlink did not meet the average three month liquidity threshold
# aave did not meet the average three month liquidity threshold
# ampleforth did not meet the average three month liquidity threshold
# trustswap did not meet the average three month liquidity threshold
# colony did not meet the average three month liquidity threshold
# xana did not meet the average three month liquidity threshold
# playa3ull-games-2 did not meet the average three month liquidity threshold
# pendle did not meet the average three month liquidity threshold
# spell-token did not meet the average three month liquidity threshold
# synapse-2 did not meet the average three month liquidity threshold
# domi did not meet the average three month liquidity threshold
# dexalot did not meet the average three month liquidity threshold
# gamer-arena did not meet the average three month liquidity threshold
# step-app-fitfi did not meet the average three month liquidity threshold
# defi-kingdoms did not meet the average three month liquidity threshold
# meld-2 did not meet the average three month liquidity threshold
# aleph did not meet the average three month liquidity threshold
# raini-studios-token did not meet the average three month liquidity threshold
# Dropping coq-inu because a price feed is unavailable
#                            avalanche optimal chain  best slippage  \
# id
# benqi-liquid-staked-avax   -0.005518     avalanche      -0.005518
# coq-inu                    -0.073213     avalanche      -0.073213
# benqi                      -0.083702     avalanche      -0.083702
# avalaunch                  -0.101230     avalanche      -0.101230
# joe                        -0.115844     avalanche      -0.115844
# aleph                      -0.287998          None      -0.287998
# ampleforth                 -0.315765          None      -0.315765
# aave                       -0.316596          None      -0.316596
# colony                     -0.368049          None      -0.368049
# playa3ull-games-2          -0.397699          None      -0.397699
# chainlink                  -0.439606          None      -0.439606
# gamer-arena                -0.453007          None      -0.453007
# dexalot                    -0.701694          None      -0.701694
# trustswap                  -0.754801          None      -0.754801
# xana                       -0.767719          None      -0.767719
# raini-studios-token        -0.772693          None      -0.772693
# meld-2                     -0.898558          None      -0.898558
# spell-token                -0.901203          None      -0.901203
# defi-kingdoms              -0.925900          None      -0.925900
# synapse-2                  -0.930542          None      -0.930542
# step-app-fitfi             -0.940739          None      -0.940739
# snowbank                   -0.949507          None      -0.949507
# gogopool-ggavax            -0.968311          None      -0.968311
# baklava                    -0.977057          None      -0.977057
# beta-finance               -0.981311          None      -0.981311
# sushi                      -0.982948          None      -0.982948
# frax-share                 -0.991801          None      -0.991801
# insure                     -0.991849          None      -0.991849
# alpha-finance              -0.992276          None      -0.992276
# uniswap                    -0.996845          None      -0.996845
# balancer                   -0.997106          None      -0.997106
# woo-network                -0.997733          None      -0.997733
# ferrum-network             -0.997900          None      -0.997900
# 1inch                      -0.998836          None      -0.998836
# dextf                      -0.999283          None      -0.999283
# maker                      -0.999413          None      -0.999413
# basic-attention-token      -0.999600          None      -0.999600
# yearn-finance              -0.999825          None      -0.999825
# the-graph                  -0.999839          None      -0.999839
# 0x                         -0.999898          None      -0.999898
# compound-governance-token  -0.999904          None      -0.999904
# uma                        -0.999940          None      -0.999940
# deapcoin                   -1.000000          None      -1.000000
# orbs                       -1.000000          None      -1.000000
#
#                            optimal slippage best slippage chain  \
# id
# benqi-liquid-staked-avax          -0.005518           avalanche
# coq-inu                           -0.073213           avalanche
# benqi                             -0.083702           avalanche
# avalaunch                         -0.101230           avalanche
# joe                               -0.115844           avalanche
# aleph                             -0.287998           avalanche
# ampleforth                        -0.315765           avalanche
# aave                              -0.316596           avalanche
# colony                            -0.368049           avalanche
# playa3ull-games-2                 -0.397699           avalanche
# chainlink                         -0.439606           avalanche
# gamer-arena                       -0.453007           avalanche
# dexalot                           -0.701694           avalanche
# trustswap                         -0.754801           avalanche
# xana                              -0.767719           avalanche
# raini-studios-token               -0.772693           avalanche
# meld-2                            -0.898558           avalanche
# spell-token                       -0.901203           avalanche
# defi-kingdoms                     -0.925900           avalanche
# synapse-2                         -0.930542           avalanche
# step-app-fitfi                    -0.940739           avalanche
# snowbank                          -0.949507           avalanche
# gogopool-ggavax                   -0.968311           avalanche
# baklava                           -0.977057           avalanche
# beta-finance                      -0.981311           avalanche
# sushi                             -0.982948           avalanche
# frax-share                        -0.991801           avalanche
# insure                            -0.991849           avalanche
# alpha-finance                     -0.992276           avalanche
# uniswap                           -0.996845           avalanche
# balancer                          -0.997106           avalanche
# woo-network                       -0.997733           avalanche
# ferrum-network                    -0.997900           avalanche
# 1inch                             -0.998836           avalanche
# dextf                             -0.999283           avalanche
# maker                             -0.999413           avalanche
# basic-attention-token             -0.999600           avalanche
# yearn-finance                     -0.999825           avalanche
# the-graph                         -0.999839           avalanche
# 0x                                -0.999898           avalanche
# compound-governance-token         -0.999904           avalanche
# uma                               -0.999940           avalanche
# deapcoin                          -1.000000           avalanche
# orbs                              -1.000000           avalanche
#
#                            liquidity score
# id
# benqi-liquid-staked-avax        100.000000
# coq-inu                          93.261062
# benqi                            92.216841
# avalaunch                        90.471952
# joe                              89.017149
# aleph                            71.879293
# ampleforth                       69.115167
# aave                             69.032381
# colony                           63.910315
# playa3ull-games-2                60.958627
# chainlink                        56.786846
# gamer-arena                      55.452737
# dexalot                          30.696152
# trustswap                        25.409406
# xana                             24.123401
# raini-studios-token              23.628229
# meld-2                           11.098468
# spell-token                      10.835220
# defi-kingdoms                     8.376601
# synapse-2                         7.914492
# step-app-fitfi                    6.899402
# snowbank                          6.026522
# gogopool-ggavax                   4.154575
# baklava                           3.283917
# beta-finance                      2.860486
# sushi                             2.697542
# frax-share                        1.816166
# insure                            1.811438
# alpha-finance                     1.768893
# uniswap                           1.314101
# balancer                          1.288102
# woo-network                       1.225691
# ferrum-network                    1.209091
# 1inch                             1.115852
# dextf                             1.071360
# maker                             1.058476
# basic-attention-token             1.039825
# yearn-finance                     1.017405
# the-graph                         1.016003
# 0x                                1.010148
# compound-governance-token         1.009538
# uma                               1.006000
# deapcoin                          1.000000
# orbs                              1.000000

# %% [markdown]
# ## Show Results

# %%
results
# Out:
#                          symbol    market_cap    weight  weight_converted  \
# benqi-liquid-staked-avax  sAVAX  2.000000e+10  0.500000               128
# joe                         JOE  9.980358e+07  0.277359                71
# benqi                        QI  5.969934e+07  0.171871                44
# avalaunch                  XAVA  1.797544e+07  0.050771                12
#
#                                                              address  \
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi                     0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# avalaunch                 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
#
#                          blockchain
# benqi-liquid-staked-avax  avalanche
# joe                       avalanche
# benqi                     avalanche
# avalaunch                 avalanche

# %% [markdown]
# ## Contract Output

# %%
methodology_class.output_for_contract()
# Out:
# 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,0x8729438eb15e2c8b576fcc6aecda6a148776c0f5,0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# 128,71,44,12
