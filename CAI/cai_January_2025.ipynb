# %% [markdown]
# ## CAI - Colony Avalanche Index - Rebalancing data for January 2025

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import decouple
import sys
sys.path.append('../')
from methodology import MethodologyProd
from pycoingecko import CoinGeckoAPI
key =  decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key=key)

# %% [markdown]
# ## Index Variables

# %%
date = '2025-01-01'
min_mcap =  0.1e8
min_weight = 0.005
max_weight = 0.3
circ_supply_threshold = 0.3
liveness_threshold = 180 # In days
liquidity_consistency = 90 # In days
coingecko_category = ["avalanche-ecosystem"]

# Calculating max slippage based on liquidity threshold
liq = 2*1e6
liq_os = liq / 2 # one-side liquidity 
trade_value_tiny = 1e2
trade_value = 1e5
max_slippage = (liq_os + trade_value_tiny) / (liq_os + trade_value) - 1
# round to the nearest .01
max_slippage = round(max_slippage, 2)

# Dataframes to remove
stablecoins = pd.DataFrame(cg.get_coins_markets('usd',category='stablecoins')).set_index('id')
ctokens = pd.DataFrame(cg.get_coins_markets('usd',category='compound-tokens')).set_index('id')
atokens = pd.DataFrame(cg.get_coins_markets('usd',category='aave-tokens')).set_index('id')

methodology_class = MethodologyProd(
                                date,
                                1,
                                "avalanche",
                                "0x48f88A3fE843ccb0b5003e70B4192c1d7448bEf0",
                                "cai_benchmark_data",
                                "cai_liquidities",
                                min_mcap,
                                min_weight,
                                max_weight,
                                100000,
                                255,
                                circ_supply_threshold,
                                liveness_threshold,
                                liquidity_consistency,
                                -0.15,
                                coingecko_category)

# %% [markdown]
# ## Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data at least 6 months prior to the date of inclusion in the index.
#     1. The project should have a token that is native to Avalanche. This excludes wrapped variants, where the underlying tokens are locked on an alt-L1.
#     1. The project should be a going concern, with a dedicated team actively building, supporting and maintaining the project.
#     1. No rebasing or deflationary tokens.
#     1. The project must be widely considered to be building a useful protocol or product. Projects that have ponzi characteristics at the core of their offering will not be considered.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project’s protocol or product must have significant usage.
#     <br>
# 1. **Pricing requirements**
#     1. Token should have a Chainlink price feed to allow for manipulation resistant pricing.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 30% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The token must have shown consistent DeFi liquidity on Avalanche.
#     1. The token must experience less than 15% price impact for a $100k trade in both directions.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.

# %% [markdown]
# ## Run Methodology

# %%
results,liquidity = methodology_class.main(
    single_chain="avalanche",
    df_to_remove=[stablecoins,ctokens,atokens],
    ids_to_replace=[["avalanche-2"],["benqi-liquid-staked-avax"]],
    remove_category_assets=['wrapped-bitcoin',"gmx","euro-coin","bitcoin-avalanche-bridged-btc-b","benqi-liquid-staked-avax","pangolin"],
    values_to_update=[{'id':'pangolin','category':'total_supply','value':230000000},
                      {'id':'benqi-liquid-staked-avax','category':'market_cap','value':20000000000},
                      {'id':'benqi-liquid-staked-avax','category':'symbol','value':"sAVAX"}
                      ],
    enable_liquidity_score=True,
    weight_split_data= {"asset_to_split":"benqi-liquid-staked-avax","asset_to_receive":"gogopool-ggavax","split_ratio":0.5},
    individual_asset_weight={"coq-inu":0.05},
    onchain_oracles=["coq-inu","gogopool","gogopool-ggavax",'benqi','avalaunch','joe','benqi-liquid-staked-avax','colony']

    )
liquidity
# Out:
# Excluding solv-protocol-solvbtc-bbn, pricing data available only for 154 < 180 days
# Excluding avalanche-bridged-weth-avalanche, pricing data available only for 141 < 180 days
# Excluding avalanche-old-bridged-wbtc-avalanche, pricing data available only for 152 < 180 days
# Excluding kepler, pricing data available only for 30 < 180 days
# Excluding big, pricing data available only for 22 < 180 days
# Excluding avalanche-bridged-dai-avalanche, pricing data available only for 137 < 180 days
# Excluding ai9000, pricing data available only for 17 < 180 days
# Excluding nya, pricing data available only for 120 < 180 days
# Table created successfully
# Table created successfully
# solv-btc on avalanche returned an invalid API response
# solv-btc recorded no valid response across any platform
# havven on avalanche returned an invalid API response
# havven recorded no valid response across any platform
# axelar on avalanche returned an invalid API response
# axelar recorded no valid response across any platform
# ankr on avalanche returned an invalid API response
# ankr recorded no valid response across any platform
# ampleforth on avalanche returned an invalid API response
# ampleforth recorded no valid response across any platform
# cartesi on avalanche returned an invalid API response
# cartesi recorded no valid response across any platform
# telos on avalanche returned an invalid API response
# telos recorded no valid response across any platform
# kyber-network-crystal on avalanche returned an invalid API response
# kyber-network-crystal recorded no valid response across any platform
# ox-fun on avalanche returned an invalid API response
# ox-fun recorded no valid response across any platform
# ankreth on avalanche returned an invalid API response
# ankreth recorded no valid response across any platform
# idia on avalanche returned an invalid API response
# idia recorded no valid response across any platform
# allianceblock-nexera on avalanche returned an invalid API response
# allianceblock-nexera recorded no valid response across any platform
# miracle-play on avalanche returned an invalid API response
# miracle-play recorded no valid response across any platform
# tarot-2 on avalanche returned an invalid API response
# tarot-2 recorded no valid response across any platform
# vnx-swiss-franc on avalanche returned an invalid API response
# vnx-swiss-franc recorded no valid response across any platform
# chainlink did not meet the average three month liquidity threshold
# aave did not meet the average three month liquidity threshold
# ampleforth did not meet the average three month liquidity threshold
# trustswap did not meet the average three month liquidity threshold
# xana did not meet the average three month liquidity threshold
# playa3ull-games-2 did not meet the average three month liquidity threshold
# osaka-protocol did not meet the average three month liquidity threshold
# spell-token did not meet the average three month liquidity threshold
# synapse-2 did not meet the average three month liquidity threshold
# dexalot did not meet the average three month liquidity threshold
# gamer-arena did not meet the average three month liquidity threshold
# defi-kingdoms did not meet the average three month liquidity threshold
# aleph did not meet the average three month liquidity threshold
# beam-2 did not meet the average three month liquidity threshold
# Dropping wrapped-avax because a price feed is unavailable
# Dropping usd-coin-avalanche-bridged-usdc-e because a price feed is unavailable
#                                    avalanche optimal chain  best slippage  \
# id
# usd-coin-avalanche-bridged-usdc-e  -0.000083     avalanche      -0.000083
# gogopool-ggavax                    -0.000765     avalanche      -0.000765
# wrapped-avax                       -0.001242     avalanche      -0.001242
# benqi-liquid-staked-avax           -0.002242     avalanche      -0.002242
# avalaunch                          -0.050234     avalanche      -0.050234
# coq-inu                            -0.052213     avalanche      -0.052213
# benqi                              -0.070914     avalanche      -0.070914
# joe                                -0.094641     avalanche      -0.094641
# gogopool                           -0.102191     avalanche      -0.102191
# colony                             -0.127809     avalanche      -0.127809
# aave                               -0.152132          None      -0.152132
# chainlink                          -0.216935          None      -0.216935
# playa3ull-games-2                  -0.310023          None      -0.310023
# beam-2                             -0.346038          None      -0.346038
# osaka-protocol                     -0.496861          None      -0.496861
# gamer-arena                        -0.523235          None      -0.523235
# dexalot                            -0.644154          None      -0.644154
# trustswap                          -0.709406          None      -0.709406
# synapse-2                          -0.898899          None      -0.898899
# spell-token                        -0.909238          None      -0.909238
# defi-kingdoms                      -0.917816          None      -0.917816
# snowbank                           -0.936381          None      -0.936381
# xen-crypto                         -0.962758          None      -0.962758
# sushi                              -0.967885          None      -0.967885
# balancer                           -0.972608          None      -0.972608
# beta-finance                       -0.980540          None      -0.980540
# frax-share                         -0.987142          None      -0.987142
# alpha-finance                      -0.992170          None      -0.992170
# uniswap                            -0.995107          None      -0.995107
# woo-network                        -0.996542          None      -0.996542
# 1inch                              -0.998354          None      -0.998354
# dextf                              -0.999087          None      -0.999087
# basic-attention-token              -0.999500          None      -0.999500
# deapcoin                           -0.999577          None      -0.999577
# yearn-finance                      -0.999785          None      -0.999785
# the-graph                          -0.999809          None      -0.999809
# insure                             -0.999832          None      -0.999832
# wagmi-2                            -0.999898          None      -0.999898
# nuklai                             -0.999900          None      -0.999900
# orbs                               -0.999900          None      -0.999900
# uma                                -0.999900          None      -0.999900
# maker                              -0.999900          None      -0.999900
# 0x                                 -0.999900          None      -0.999900
# compound-governance-token          -0.999909          None      -0.999909
# aleph                              -1.000000          None      -1.000000
#
#                                    optimal slippage best slippage chain  \
# id
# usd-coin-avalanche-bridged-usdc-e         -0.000083           avalanche
# gogopool-ggavax                           -0.000765           avalanche
# wrapped-avax                              -0.001242           avalanche
# benqi-liquid-staked-avax                  -0.002242           avalanche
# avalaunch                                 -0.050234           avalanche
# coq-inu                                   -0.052213           avalanche
# benqi                                     -0.070914           avalanche
# joe                                       -0.094641           avalanche
# gogopool                                  -0.102191           avalanche
# colony                                    -0.127809           avalanche
# aave                                      -0.152132           avalanche
# chainlink                                 -0.216935           avalanche
# playa3ull-games-2                         -0.310023           avalanche
# beam-2                                    -0.346038           avalanche
# osaka-protocol                            -0.496861           avalanche
# gamer-arena                               -0.523235           avalanche
# dexalot                                   -0.644154           avalanche
# trustswap                                 -0.709406           avalanche
# synapse-2                                 -0.898899           avalanche
# spell-token                               -0.909238           avalanche
# defi-kingdoms                             -0.917816           avalanche
# snowbank                                  -0.936381           avalanche
# xen-crypto                                -0.962758           avalanche
# sushi                                     -0.967885           avalanche
# balancer                                  -0.972608           avalanche
# beta-finance                              -0.980540           avalanche
# frax-share                                -0.987142           avalanche
# alpha-finance                             -0.992170           avalanche
# uniswap                                   -0.995107           avalanche
# woo-network                               -0.996542           avalanche
# 1inch                                     -0.998354           avalanche
# dextf                                     -0.999087           avalanche
# basic-attention-token                     -0.999500           avalanche
# deapcoin                                  -0.999577           avalanche
# yearn-finance                             -0.999785           avalanche
# the-graph                                 -0.999809           avalanche
# insure                                    -0.999832           avalanche
# wagmi-2                                   -0.999898           avalanche
# nuklai                                    -0.999900           avalanche
# orbs                                      -0.999900           avalanche
# uma                                       -0.999900           avalanche
# maker                                     -0.999900           avalanche
# 0x                                        -0.999900           avalanche
# compound-governance-token                 -0.999909           avalanche
# aleph                                     -1.000000           avalanche
#
#                                    liquidity score
# id
# usd-coin-avalanche-bridged-usdc-e       100.000000
# gogopool-ggavax                          99.932442
# wrapped-avax                             99.885210
# benqi-liquid-staked-avax                 99.786265
# avalaunch                                95.034664
# coq-inu                                  94.838703
# benqi                                    92.987160
# joe                                      90.637949
# gogopool                                 89.890482
# colony                                   87.354098
# aave                                     84.945929
# chainlink                                78.529870
# playa3ull-games-2                        69.313372
# beam-2                                   65.747589
# osaka-protocol                           50.814908
# gamer-arena                              48.203661
# dexalot                                  36.231625
# trustswap                                29.771220
# synapse-2                                11.009874
# spell-token                               9.986201
# defi-kingdoms                             9.136868
# snowbank                                  7.298787
# xen-crypto                                4.687305
# sushi                                     4.179653
# balancer                                  3.712074
# beta-finance                              2.926704
# frax-share                                2.273009
# alpha-finance                             1.775229
# uniswap                                   1.484449
# woo-network                               1.342393
# 1inch                                     1.162956
# dextf                                     1.090379
# basic-attention-token                     1.049498
# deapcoin                                  1.041890
# yearn-finance                             1.021238
# the-graph                                 1.018877
# insure                                    1.016586
# wagmi-2                                   1.010087
# nuklai                                    1.009904
# orbs                                      1.009904
# uma                                       1.009901
# maker                                     1.009901
# 0x                                        1.009901
# compound-governance-token                 1.008997
# aleph                                     1.000000

# %% [markdown]
# ## Show Results

# %%
results
# Out:
#                           symbol    market_cap    weight  weight_converted  \
# joe                          JOE  1.499426e+08  0.284587                73
# benqi                         QI  8.725269e+07  0.169896                44
# benqi-liquid-staked-avax   sAVAX  2.000000e+10  0.150000                39
# gogopool-ggavax           GGAVAX  3.543156e+07  0.150000                39
# gogopool                     GGP  6.438678e+07  0.121197                30
# coq-inu                      COQ  9.661804e+07  0.050000                12
# avalaunch                   XAVA  2.209703e+07  0.043974                11
# colony                       CLY  1.658967e+07  0.030346                 7
#
#                                                              address  \
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi                     0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# gogopool-ggavax           0xa25eaf2906fa1a3a13edac9b9657108af7b703e3
# gogopool                  0x69260b9483f9871ca57f81a90d91e2f96c2cd11d
# coq-inu                   0x420fca0121dc28039145009570975747295f2329
# avalaunch                 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# colony                    0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
#
#                          blockchain
# joe                       avalanche
# benqi                     avalanche
# benqi-liquid-staked-avax  avalanche
# gogopool-ggavax           avalanche
# gogopool                  avalanche
# coq-inu                   avalanche
# avalaunch                 avalanche
# colony                    avalanche

# %% [markdown]
# ## Contract Output

# %%
methodology_class.output_for_contract()
# Out:
# 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,0x420fca0121dc28039145009570975747295f2329,0x69260b9483f9871ca57f81a90d91e2f96c2cd11d,0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,0x8729438eb15e2c8b576fcc6aecda6a148776c0f5,0xa25eaf2906fa1a3a13edac9b9657108af7b703e3,0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4,0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
# 39,12,30,73,44,39,11,7

# %%
methodology_class.show_results().drop(columns=["weight_converted"])
# Out:
#                           symbol    market_cap    weight  \
# joe                          JOE  1.499426e+08  0.284587
# benqi                         QI  8.725269e+07  0.169896
# benqi-liquid-staked-avax   sAVAX  2.000000e+10  0.150000
# gogopool-ggavax           GGAVAX  3.543156e+07  0.150000
# gogopool                     GGP  6.438678e+07  0.121197
# coq-inu                      COQ  9.661804e+07  0.050000
# avalaunch                   XAVA  2.209703e+07  0.043974
# colony                       CLY  1.658967e+07  0.030346
#
#                                                              address  \
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi                     0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# gogopool-ggavax           0xa25eaf2906fa1a3a13edac9b9657108af7b703e3
# gogopool                  0x69260b9483f9871ca57f81a90d91e2f96c2cd11d
# coq-inu                   0x420fca0121dc28039145009570975747295f2329
# avalaunch                 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# colony                    0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
#
#                          blockchain
# joe                       avalanche
# benqi                     avalanche
# benqi-liquid-staked-avax  avalanche
# gogopool-ggavax           avalanche
# gogopool                  avalanche
# coq-inu                   avalanche
# avalaunch                 avalanche
# colony                    avalanche
