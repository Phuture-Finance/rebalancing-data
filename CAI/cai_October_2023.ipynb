# %% [markdown]
# ## CAI - Rebalancing data for October 2023

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import numpy as np
import requests
import decouple
import sys 
import datetime
import time
sys.path.append('../')

from web3 import Web3
from abis import index_anatomy


infura_url = decouple.config("AVALANCHE_INFURA_URL")
web3_object = Web3(Web3.HTTPProvider(infura_url))

import db_funcs

# %%
from pycoingecko import CoinGeckoAPI
key = decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key= key)

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Index Variables and settings

# %%
db_key_date = '2023-10-01'
db_liquidity_table = 'cai_liquidities'
db_benchmark_table = 'cai_benchmark_data'
min_weight = 0.005
max_weight = 0.5
supply_threshold = 0.3
liquidity_consistency = 90 # In days
avax_to_savax_split = 0.6
liveness_threshold = 30*6 # In days

# %%
liq = 2*10**6
liq_os = liq / 2 # one-side liquidity 
trade_value_tiny = 1e2
trade_value = 1e5
max_slippage = (liq_os + trade_value_tiny) / (liq_os + trade_value) - 1
# round to the nearest .5
max_slippage = round(2 * max_slippage, 2) / 2 
max_slippage
# Out:
# -0.09

# %% [markdown]
# ## Data retrieving and filtering

# %% [markdown]
# ### Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data at least 6 months prior to the date of inclusion in the index.
#     1. The project should have a token that is native to Avalanche. This excludes wrapped variants, where the underlying tokens are locked on an alt-L1.
#     1. The project should be a going concern, with a dedicated team actively building, supporting and maintaining the project.
#     1. No rebasing or deflationary tokens.
#     1. The project must be widely considered to be building a useful protocol or product. Projects that have ponzi characteristics at the core of their offering will not be considered.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project’s protocol or product must have significant usage.
#     <br>
# 1. **Pricing requirements**
#     1. Token should have a Chainlink price feed to allow for manipulation resistant pricing.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 30% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The token should have in aggregate at least $2mm of onchain liquidity across Trader Joe, Platypus, Pangolin.
#     1. The token must have shown consistent DeFi liquidity on Avalanche.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.

# %% [markdown]
# ### Tokens list

# %%
def normalize_symb(symb):
    return ''.join(c for c in symb if c.isalnum()).upper()

# %% [markdown]
# #### CoinGecko

# %% [markdown]
# ##### Tokens addresses

# %%
coins_list = cg.get_coins_list(include_platform=True)
coins = {}
for coin in coins_list:
    if 'avalanche' in coin['platforms']:
        coin['addr'] = coin['platforms']['avalanche']
        coin['symbol'] = normalize_symb(coin['symbol'])
        coins[coin['id']] = coin

# Adding AVAX
coins['avalanche-2'] = {'id': 'avalanche-2','symbol':normalize_symb('avax'), 'name':'Avalanche','addr':'0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7',}

# %% [markdown]
# ##### Market data

# %%
cat_id = "avalanche-ecosystem"
cg_tokens_data = cg.get_coins_markets(vs_currency='USD', order='market_cap_desc', category=cat_id)
for i in range(2, 30):
    cg_tokens_data.extend(cg.get_coins_markets(vs_currency='USD', order='market_cap_desc', category=cat_id, page=i))
    
cg_tokens_data = pd.DataFrame.from_records(cg_tokens_data)


#print(cg.get_coins_markets(ids='avalanche-2',vs_currency='USD'))

cg_tokens_data = pd.concat([cg_tokens_data,pd.DataFrame(cg.get_coins_markets(ids='avalanche-2',vs_currency='USD'))],ignore_index=True)
cg_tokens_data
# Out:
#                           id symbol                     name  \
# 0                     tether   usdt                   Tether
# 1                binancecoin    bnb                      BNB
# 2                   usd-coin   usdc                     USDC
# 3            wrapped-bitcoin   wbtc          Wrapped Bitcoin
# 4                  chainlink   link                Chainlink
# ..                       ...    ...                      ...
# 326        ethereum-wormhole    eth      Ethereum (Wormhole)
# 327                evoverses    evo                EvoVerses
# 328                     zjoe   zjoe                     zJOE
# 329  backed-niu-technologies   bniu  Backed NIU Technologies
# 330              avalanche-2   avax                Avalanche
#
#                                                  image  current_price  \
# 0    https://assets.coingecko.com/coins/images/325/...       1.000000
# 1    https://assets.coingecko.com/coins/images/825/...     219.350000
# 2    https://assets.coingecko.com/coins/images/6319...       0.999924
# 3    https://assets.coingecko.com/coins/images/7598...   28337.000000
# 4    https://assets.coingecko.com/coins/images/877/...       7.930000
# ..                                                 ...            ...
# 326  https://assets.coingecko.com/coins/images/2299...    1728.520000
# 327  https://assets.coingecko.com/coins/images/2508...       0.000392
# 328  https://assets.coingecko.com/coins/images/2553...       0.163060
# 329  https://assets.coingecko.com/coins/images/3186...            NaN
# 330  https://assets.coingecko.com/coins/images/1255...       9.730000
#
#        market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0    8.328307e+10              3.0             8.328307e+10  2.365716e+10
# 1    3.377782e+10              4.0             4.390832e+10  5.449671e+08
# 2    2.527049e+10              6.0             2.527034e+10  6.311906e+09
# 3    4.617194e+09             17.0             4.617194e+09  1.572964e+08
# 4    4.409911e+09             19.0             7.919388e+09  3.818976e+08
# ..            ...              ...                      ...           ...
# 326  0.000000e+00              NaN             1.408378e+08  1.197975e+06
# 327  0.000000e+00              NaN             1.079570e+05  1.165100e+02
# 328  0.000000e+00              NaN                      NaN  2.684000e+01
# 329           NaN              NaN                      NaN           NaN
# 330  3.450144e+09             23.0             7.013359e+09  1.289824e+08
#
#          high_24h  ...  total_supply    max_supply           ath  \
# 0        1.005000  ...  8.325705e+10           NaN      1.320000
# 1      221.090000  ...  1.538562e+08  2.000000e+08    686.310000
# 2        1.004000  ...  2.526733e+10           NaN      1.170000
# 3    28386.000000  ...  1.627949e+05  1.627949e+05  70643.000000
# 4        8.160000  ...  1.000000e+09  1.000000e+09     52.700000
# ..            ...  ...           ...           ...           ...
# 326   1754.600000  ...  8.144752e+04           NaN   3892.040000
# 327      0.000394  ...  2.754408e+08           NaN      0.034352
# 328      0.169809  ...           NaN           NaN      0.467473
# 329           NaN  ...  1.600960e+05           NaN           NaN
# 330      9.810000  ...  4.315704e+08  7.200000e+08    144.960000
#
#      ath_change_percentage                  ath_date          atl  \
# 0                -24.40131  2018-07-24T00:00:00.000Z     0.572521
# 1                -68.04030  2021-05-10T07:24:17.097Z     0.039818
# 2                -14.62241  2019-05-08T00:40:28.300Z     0.877647
# 3                -59.90771  2021-11-10T14:40:19.650Z  3139.170000
# 4                -84.95357  2021-05-10T00:13:57.214Z     0.148183
# ..                     ...                       ...          ...
# 326              -55.50294  2022-03-30T16:00:34.289Z   146.450000
# 327              -98.85903  2022-07-20T07:01:41.657Z     0.000357
# 328              -65.06901  2022-05-18T01:29:44.179Z     0.087044
# 329                0.00000                      None          NaN
# 330              -93.27965  2021-11-21T14:18:56.538Z     2.800000
#
#      atl_change_percentage                  atl_date   roi  \
# 0                 74.70847  2015-03-02T00:00:00.000Z  None
# 1             550764.41614  2017-10-19T00:00:00.000Z  None
# 2                 14.08102  2023-03-11T08:02:13.981Z  None
# 3                802.22985  2019-04-02T00:00:00.000Z  None
# 4               5250.77861  2017-11-29T00:00:00.000Z  None
# ..                     ...                       ...   ...
# 326             1082.53010  2022-10-10T21:11:53.498Z  None
# 327                9.75771  2023-08-11T16:46:09.736Z  None
# 328               87.59913  2023-03-11T15:21:46.299Z  None
# 329                0.00000                      None  None
# 330              247.79284  2020-12-31T13:15:21.540Z  None
#
#                  last_updated
# 0    2023-10-02T11:35:00.447Z
# 1    2023-10-02T11:35:19.100Z
# 2    2023-10-02T11:35:23.901Z
# 3    2023-10-02T11:35:16.325Z
# 4    2023-10-02T11:35:22.800Z
# ..                        ...
# 326  2023-10-02T11:35:00.256Z
# 327  2023-10-01T14:09:16.245Z
# 328  2023-10-02T11:35:19.092Z
# 329                      None
# 330  2023-10-02T11:35:34.217Z
#
# [331 rows x 26 columns]

# %%
tokens_market_data = cg_tokens_data.set_index('id')[
    ['name', 'symbol', 'market_cap', 'market_cap_rank', 'current_price', 'total_supply', 'circulating_supply']
]
tokens_market_data['symbol'] = tokens_market_data['symbol'].apply(normalize_symb)

# %%
tokens_market_data = tokens_market_data[tokens_market_data['market_cap'] > 0]
tokens_market_data = tokens_market_data[~tokens_market_data.index.duplicated(keep='first')]
tokens_market_data = tokens_market_data.join(pd.DataFrame.from_dict(coins, orient='index')['addr'])
tokens_market_data = tokens_market_data[~tokens_market_data['addr'].isna()]

# %%
# Stable coins to remove from tokens list
stablecoins = pd.DataFrame(cg.get_coins_markets('usd',category='stablecoins')).set_index('id')

#Adjusting Pangolin's max supply to reflect tokenomic changes here: https://app.pangolin.exchange/#/vote/10
tokens_market_data.loc[['pangolin'],["total_supply"]] = 230000000.0

tokens_market_data =  tokens_market_data[~tokens_market_data.index.isin(stablecoins.index)]
tokens_market_data = tokens_market_data.sort_values('market_cap', ascending=False)

tokens_market_data
# Out:
#                             name symbol    market_cap  market_cap_rank  \
# id
# wrapped-bitcoin  Wrapped Bitcoin   WBTC  4.617194e+09             17.0
# chainlink              Chainlink   LINK  4.409911e+09             19.0
# uniswap                  Uniswap    UNI  3.514800e+09             21.0
# avalanche-2            Avalanche   AVAX  3.450144e+09             23.0
# maker                      Maker    MKR  1.344232e+09             38.0
# ...                          ...    ...           ...              ...
# ydragon                  YDragon    YDR  7.752890e+03           3509.0
# hakuswap                HakuSwap   HAKU  7.259450e+03           3514.0
# echidna                  Echidna    ECD  3.263040e+03           3556.0
# ape-in                    Ape In  APEIN  2.245910e+03           3567.0
# spice-trade          Spice Trade  SPICE  4.869500e+02           3587.0
#
#                  current_price  total_supply  circulating_supply  \
# id
# wrapped-bitcoin   28337.000000  1.627949e+05        1.627949e+05
# chainlink             7.930000  1.000000e+09        5.568500e+08
# uniswap               4.660000  1.000000e+09        7.537667e+08
# avalanche-2           9.730000  4.315704e+08        3.541961e+08
# maker              1490.550000  9.776310e+05        9.013109e+05
# ...                        ...           ...                 ...
# ydragon               0.000062  5.000000e+08        1.257806e+08
# hakuswap              0.000167  8.452850e+07        4.343500e+07
# echidna               0.000284  3.383739e+08        1.149388e+07
# ape-in                0.059891  3.750000e+04        3.750000e+04
# spice-trade           0.000334  5.762059e+07        1.457682e+06
#
#                                                        addr
# id
# wrapped-bitcoin  0x50b7545627a5162f82a992c33b87adc75187b218
# chainlink        0x5947bb275c521040051d82396192181b413227a3
# uniswap          0x8ebaf22b6f053dffeaf46f4dd9efa95d89ba8580
# avalanche-2      0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# maker            0x88128fd4b259552a9a1d457f435a6527aab72d42
# ...                                                     ...
# ydragon          0xf03dccaec9a28200a6708c686cf0b8bf26ddc356
# hakuswap         0x695fa794d59106cebd40ab5f5ca19f458c723829
# echidna          0xeb8343d5284caec921f035207ca94db6baaacbcd
# ape-in           0x938fe3788222a74924e062120e7bfac829c719fb
# spice-trade      0xf30c5083a1479865c9a8916dec6ddadd82e8907b
#
# [178 rows x 8 columns]

# %% [markdown]
# ### Token's supply check

# %%
sp_passed_index = (tokens_market_data['circulating_supply'] / tokens_market_data['total_supply']) > supply_threshold
sp_passed = tokens_market_data[sp_passed_index]

# %% [markdown]
# ### Retrieve historical data & token age check

# %%
exclude_list = []

prices_data = pd.DataFrame()
marketcaps = pd.DataFrame() 
for id_, row in sp_passed.iterrows():
    symbol = row['symbol']
    data = cg.get_coin_market_chart_by_id(id_, vs_currency='USD', days='max')
  
    df_prices = pd.DataFrame(data['prices'], columns=['date', id_])
    df_prices = df_prices[df_prices[id_] > 0]
    df_prices['date'] = pd.to_datetime(df_prices['date'], unit='ms').dt.date
    df_prices['date'] = pd.to_datetime(df_prices['date'])
    df_prices = df_prices.set_index('date', drop=True)
    df_prices = df_prices.loc[~df_prices.index.duplicated(keep='first')]
    
    if len(df_prices) < liveness_threshold:
        print(f'Excluding {symbol}, prices data available only for {len(df_prices)} < {liveness_threshold} days')
        exclude_list.append(id_)
        continue
    prices_data = pd.concat([prices_data, df_prices], axis=1)
    
    df_mcaps = pd.DataFrame(data['market_caps'], columns=['date', id_])
    df_mcaps = df_mcaps[df_mcaps[id_] > 0]
    df_mcaps['date'] = pd.to_datetime(df_mcaps['date'], unit='ms').dt.date
    df_mcaps['date'] = pd.to_datetime(df_mcaps['date'])
    df_mcaps = df_mcaps.set_index('date', drop=True)
    df_mcaps = df_mcaps.loc[~df_mcaps.index.duplicated(keep='first')]
    
    if len(df_mcaps) < liveness_threshold:
        print(f'Note: {symbol}, marketcap data available only for {len(df_mcaps)} < {liveness_threshold} days')
        ## continue
    df_mcaps = df_mcaps.reindex(df_prices.index)
    marketcaps = pd.concat([marketcaps, df_mcaps], axis=1)
# Out:
# Excluding MELD, prices data available only for 148 < 180 days
# Excluding USP, prices data available only for 13 < 180 days
# Excluding ERN, prices data available only for 176 < 180 days
# Excluding 3ULL, prices data available only for 116 < 180 days
# Note: EIV, marketcap data available only for 47 < 180 days
# Note: EUROE, marketcap data available only for 103 < 180 days
# Note: GMD, marketcap data available only for 125 < 180 days
# Note: CINU, marketcap data available only for 165 < 180 days
# Excluding GRAIN, prices data available only for 172 < 180 days
# Note: PLN, marketcap data available only for 125 < 180 days
# Note: VCHF, marketcap data available only for 3 < 180 days
# Note: NFTE, marketcap data available only for 12 < 180 days

# %% [markdown]
# ### Non quantative checks

# %%
manual_exclusions = [
    {
        'gecko_id': 'spell-token',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'stacktical',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'zookeeper',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'pendle',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'everrise',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'wrapped-bitcoin',
        'reason' : 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'bitcoin-avalanche-bridged-btc-b',
        'reason': 'Not a native Avalanche asset'
    },
    {
        'gecko_id': 'gmx',
        'reason': 'Bridged asset'
    },
    {
        'gecko_id': 'woo-network',
        'reason': 'Bridged asset'
    },
    {
        'gecko_id': 'euro-coin',
        'reason': 'Stable coin'
    }
]
for token in manual_exclusions:
    exclude_list.append(token['gecko_id'])

# %%
passed_q_and_non_q_checks = sp_passed.query('index not in @exclude_list')
passed_q_and_non_q_checks.drop(passed_q_and_non_q_checks[passed_q_and_non_q_checks['market_cap'] < 1e6].index)
# Out:
#                                                    name   symbol  \
# id
# chainlink                                     Chainlink     LINK
# uniswap                                         Uniswap      UNI
# avalanche-2                                   Avalanche     AVAX
# maker                                             Maker      MKR
# aave                                               Aave     AAVE
# the-graph                                     The Graph      GRT
# havven                                Synthetix Network      SNX
# frax-share                                   Frax Share      FXS
# compound-governance-token                      Compound     COMP
# 1inch                                             1inch    1INCH
# basic-attention-token                   Basic Attention      BAT
# ankr                                       Ankr Network     ANKR
# yearn-finance                             yearn.finance      YFI
# balancer                                       Balancer      BAL
# axelar                                           Axelar      AXL
# kyber-network-crystal             Kyber Network Crystal      KNC
# sushi                                             Sushi    SUSHI
# uma                                                 UMA      UMA
# insure                                      inSure DeFi     SURE
# cartesi                                         Cartesi     CTSI
# joe                                                 JOE      JOE
# orbs                                               Orbs     ORBS
# benqi-liquid-staked-avax       BENQI Liquid Staked AVAX    SAVAX
# alpha-finance                                    Stella    ALPHA
# synapse-2                                       Synapse      SYN
# beta-finance                               Beta Finance     BETA
# ankreth                                 Ankr Staked ETH  ANKRETH
# allianceblock-nexera               AllianceBlock Nexera     NXRA
# snowbank                                       Snowbank       SB
# beefy-finance                                     Beefy     BIFI
# ampleforth                                   Ampleforth     AMPL
# benqi                                             BENQI       QI
# xen-crypto                                   XEN Crypto      XEN
# step-app-fitfi                                 Step App    FITFI
# trustswap                                     TrustSwap     SWAP
# dextf                                   Domani Protocol    DEXTF
# kalmar                                             KALM     KALM
# idia                       Impossible Finance Launchpad     IDIA
# rai                                    Rai Reflex Index      RAI
# avalaunch                                     Avalaunch     XAVA
# realfevr                                       RealFevr     FEVR
# colony                                           Colony      CLY
# oath                                               OATH     OATH
# spookyswap                                   Spookyswap      BOO
# pangolin                                       Pangolin      PNG
# metagamz                                     Earniverse      EIV
# ferrum-network                           Ferrum Network      FRM
# checkdot                                       CheckDot      CDT
# yield-yak                                     Yield Yak      YAK
# defi-yield-protocol                              Dypius      DYP
# insurace                                       InsurAce    INSUR
# euroe-stablecoin                       EUROe Stablecoin    EUROE
# gmd-protocol                                        GMD      GMD
# tomb                                               Tomb     TOMB
# betswirl                                       BetSwirl     BETS
# juggernaut                                   Juggernaut      JGN
# cheems-inu-new                         Cheems Inu [NEW]     CINU
# qi-dao                                           Qi Dao       QI
# build                                             BUILD    BUILD
#
#                              market_cap  market_cap_rank  current_price  \
# id
# chainlink                  4.409911e+09             19.0   7.930000e+00
# uniswap                    3.514800e+09             21.0   4.660000e+00
# avalanche-2                3.450144e+09             23.0   9.730000e+00
# maker                      1.344232e+09             38.0   1.490550e+03
# aave                       1.024344e+09             45.0   7.014000e+01
# the-graph                  8.525801e+08             47.0   9.232700e-02
# havven                     6.984660e+08             55.0   2.150000e+00
# frax-share                 4.208120e+08             88.0   5.660000e+00
# compound-governance-token  3.297931e+08            107.0   4.806000e+01
# 1inch                      2.859989e+08            115.0   2.768810e-01
# basic-attention-token      2.722429e+08            117.0   1.827540e-01
# ankr                       2.059005e+08            156.0   2.057934e-02
# yearn-finance              1.805006e+08            170.0   5.437870e+03
# balancer                   1.507739e+08            189.0   3.470000e+00
# axelar                     1.413961e+08            195.0   3.375260e-01
# kyber-network-crystal      1.248176e+08            210.0   6.857640e-01
# sushi                      1.186825e+08            216.0   6.152730e-01
# uma                        1.068406e+08            234.0   1.440000e+00
# insure                     1.014102e+08            239.0   3.827700e-03
# cartesi                    1.008757e+08            240.0   1.371290e-01
# joe                        8.938757e+07            255.0   2.615390e-01
# orbs                       7.564661e+07            299.0   2.353211e-02
# benqi-liquid-staked-avax   7.074822e+07            319.0   1.077000e+01
# alpha-finance              6.693892e+07            331.0   8.136800e-02
# synapse-2                  6.298298e+07            346.0   3.311510e-01
# beta-finance               5.784068e+07            368.0   7.877000e-02
# ankreth                    5.474818e+07            375.0   1.954450e+03
# allianceblock-nexera       4.221426e+07            443.0   5.593300e-02
# snowbank                   3.588327e+07            479.0   2.245400e+02
# beefy-finance              2.956389e+07            545.0   3.694500e+02
# ampleforth                 2.613156e+07            578.0   1.270000e+00
# benqi                      2.186202e+07            620.0   5.413890e-03
# xen-crypto                 9.914928e+06            892.0   4.052490e-07
# step-app-fitfi             9.347157e+06            915.0   4.384310e-03
# trustswap                  8.896942e+06            948.0   8.886000e-02
# dextf                      8.041524e+06            983.0   1.414190e-01
# kalmar                     7.941362e+06            989.0   9.626320e-01
# idia                       6.801516e+06           1044.0   9.792290e-03
# rai                        6.532273e+06           1061.0   2.740000e+00
# avalaunch                  5.771049e+06           1116.0   1.693700e-01
# realfevr                   5.306691e+06           1144.0   4.159400e-04
# colony                     4.515762e+06           1202.0   4.840935e-02
# oath                       3.956260e+06           1253.0   3.237270e-02
# spookyswap                 3.788239e+06           1274.0   3.806700e-01
# pangolin                   3.660011e+06           1288.0   1.949169e-02
# metagamz                   3.230280e+06           1346.0   4.067900e-04
# ferrum-network             3.048929e+06           1379.0   2.625375e-02
# checkdot                   2.992903e+06           1385.0   4.045210e-01
# yield-yak                  2.712067e+06           1437.0   2.709200e+02
# defi-yield-protocol        2.662178e+06           1442.0   1.101010e-01
# insurace                   2.642391e+06           1444.0   4.126647e-02
# euroe-stablecoin           2.579815e+06           1458.0   1.044000e+00
# gmd-protocol               2.549418e+06           1463.0   4.312000e+01
# tomb                       2.457109e+06           1489.0   7.941310e-03
# betswirl                   2.099066e+06           1561.0   3.961000e-04
# juggernaut                 1.947536e+06           1600.0   1.942533e-02
# cheems-inu-new             1.651729e+06           1677.0   2.982700e-04
# qi-dao                     1.616804e+06           1689.0   1.927406e-02
# build                      1.452984e+06           1739.0   1.485300e-04
#
#                            total_supply  circulating_supply  \
# id
# chainlink                  1.000000e+09        5.568500e+08
# uniswap                    1.000000e+09        7.537667e+08
# avalanche-2                4.315704e+08        3.541961e+08
# maker                      9.776310e+05        9.013109e+05
# aave                       1.600000e+07        1.457929e+07
# the-graph                  1.000000e+10        9.235807e+09
# havven                     3.248085e+08        3.240846e+08
# frax-share                 9.968150e+07        7.424780e+07
# compound-governance-token  1.000000e+07        6.856086e+06
# 1inch                      1.500000e+09        1.031640e+09
# basic-attention-token      1.500000e+09        1.489973e+09
# ankr                       1.000000e+10        1.000000e+10
# yearn-finance              3.666600e+04        3.318357e+04
# balancer                   5.938978e+07        4.341906e+07
# axelar                     1.100999e+09        4.188927e+08
# kyber-network-crystal      2.287725e+08        1.816727e+08
# sushi                      2.497571e+08        1.927893e+08
# uma                        1.155103e+08        7.418808e+07
# insure                     8.800000e+10        2.646328e+10
# cartesi                    1.000000e+09        7.354706e+08
# joe                        4.764376e+08        3.414594e+08
# orbs                       1.000000e+10        3.217486e+09
# benqi-liquid-staked-avax   6.561828e+06        6.561828e+06
# alpha-finance              1.000000e+09        8.220000e+08
# synapse-2                  1.849078e+08        1.901176e+08
# beta-finance               1.000000e+09        7.378788e+08
# ankreth                    2.796986e+04        2.796986e+04
# allianceblock-nexera       8.500000e+08        7.531629e+08
# snowbank                   1.596400e+05        1.596400e+05
# beefy-finance              8.000000e+04        8.000000e+04
# ampleforth                 2.526693e+07        2.057428e+07
# benqi                      7.200000e+09        4.030421e+09
# xen-crypto                 2.448177e+13        2.446099e+13
# step-app-fitfi             4.600000e+09        2.131466e+09
# trustswap                  9.999516e+07        9.999516e+07
# dextf                      1.000000e+08        5.683824e+07
# kalmar                     1.000000e+07        8.258694e+06
# idia                       1.000000e+09        6.964680e+08
# rai                        2.379408e+06        2.379408e+06
# avalaunch                  1.000000e+08        3.408220e+07
# realfevr                   1.600000e+10        1.274968e+10
# colony                     1.500000e+08        9.320843e+07
# oath                       1.355139e+08        1.221768e+08
# spookyswap                 5.739882e+06        9.915805e+06
# pangolin                   2.300000e+08        1.875960e+08
# metagamz                   7.911203e+09        7.911203e+09
# ferrum-network             3.317187e+08        1.155314e+08
# checkdot                   9.999250e+06        7.390041e+06
# yield-yak                  1.000000e+04        1.000000e+04
# defi-yield-protocol        2.496343e+07        2.410904e+07
# insurace                   1.000000e+08        6.416752e+07
# euroe-stablecoin           2.472338e+06        2.472338e+06
# gmd-protocol               8.000000e+04        5.914673e+04
# tomb                       3.092072e+08        3.092072e+08
# betswirl                   7.341277e+09        5.296293e+09
# juggernaut                 1.500000e+08        1.002104e+08
# cheems-inu-new             9.681067e+09        5.536450e+09
# qi-dao                     2.000000e+08        8.388022e+07
# build                      1.265744e+10        9.791244e+09
#
#                                                                  addr
# id
# chainlink                  0x5947bb275c521040051d82396192181b413227a3
# uniswap                    0x8ebaf22b6f053dffeaf46f4dd9efa95d89ba8580
# avalanche-2                0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# maker                      0x88128fd4b259552a9a1d457f435a6527aab72d42
# aave                       0x63a72806098bd3d9520cc43356dd78afe5d386d9
# the-graph                  0x8a0cac13c7da965a312f08ea4229c37869e85cb9
# havven                     0xbec243c995409e6520d7c41e404da5deba4b209b
# frax-share                 0x214db107654ff987ad859f34125307783fc8e387
# compound-governance-token  0xc3048e19e76cb9a3aa9d77d8c03c29fc906e2437
# 1inch                      0xd501281565bf7789224523144fe5d98e8b28f267
# basic-attention-token      0x98443b96ea4b0858fdf3219cd13e98c7a4690588
# ankr                       0x20cf1b6e9d856321ed4686877cf4538f2c84b4de
# yearn-finance              0x9eaac1b23d935365bd7b542fe22ceee2922f52dc
# balancer                   0xe15bcb9e0ea69e6ab9fa080c4c4a5632896298c3
# axelar                     0x44c784266cf024a60e8acf2427b9857ace194c5d
# kyber-network-crystal      0x39fc9e94caeacb435842fadedecb783589f50f5f
# sushi                      0x37b608519f91f70f2eeb0e5ed9af4061722e4f76
# uma                        0x3bd2b1c7ed8d396dbb98ded3aebb41350a5b2339
# insure                     0x5fc17416925789e0852fbfcd81c490ca4abc51f9
# cartesi                    0x6b289cceaa8639e3831095d75a3e43520fabf552
# joe                        0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# orbs                       0x3ab1c9adb065f3fca0059652cd7a52b05c98f9a9
# benqi-liquid-staked-avax   0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# alpha-finance              0x2147efff675e4a4ee1c2f918d181cdbd7a8e208f
# synapse-2                  0x1f1e7c893855525b303f99bdf5c3c05be09ca251
# beta-finance               0x511d35c52a3c244e7b8bd92c0c297755fbd89212
# ankreth                    0x12d8ce035c5de3ce39b1fdd4c1d5a745eaba3b8c
# allianceblock-nexera       0x644192291cc835a93d6330b24ea5f5fedd0eef9e
# snowbank                   0x7d1232b90d3f809a54eeaeebc639c62df8a8942f
# beefy-finance              0xd6070ae98b8069de6b494332d1a1a81b6179d960
# ampleforth                 0x027dbca046ca156de9622cd1e2d907d375e53aa7
# benqi                      0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# xen-crypto                 0xc0c5aa69dbe4d6dddfbc89c0957686ec60f24389
# step-app-fitfi             0x714f020c54cc9d104b6f4f6998c63ce2a31d1888
# trustswap                  0xc7b5d72c836e718cda8888eaf03707faef675079
# dextf                      0x03e8d118a1864c7dc53bf91e007ab7d91f5a06fa
# kalmar                     0x62aceea3e666c5706ce1c61055fac1a669d31d93
# idia                       0xfcaf13227dcbfa2dc2b1928acfca03b85e2d25dd
# rai                        0x97cd1cfe2ed5712660bb6c14053c0ecb031bff7d
# avalaunch                  0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# realfevr                   0x73178fceb736a9d6c1a9ef1fe413f09cba2d4a68
# colony                     0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
# oath                       0x2c69095d81305f1e3c6ed372336d407231624cea
# spookyswap                 0xbd83010eb60f12112908774998f65761cf9f6f9a
# pangolin                   0x60781c2586d68229fde47564546784ab3faca982
# metagamz                   0xe9d62a1daffaa10e4f239936972807955ad765b4
# ferrum-network             0xe5caef4af8780e59df925470b050fb23c43ca68c
# checkdot                   0x0cbd6fadcf8096cc9a43d90b45f65826102e3ece
# yield-yak                  0x59414b3089ce2af0010e7523dea7e2b35d776ec7
# defi-yield-protocol        0x961c8c0b1aad0c0b10a51fef6a867e3091bcef17
# insurace                   0x544c42fbb96b39b21df61cf322b5edc285ee7429
# euroe-stablecoin           0x820802fa8a99901f52e39acd21177b0be6ee2974
# gmd-protocol               0x1fe70939c2cec8f31e8f7729442658586b469972
# tomb                       0xb84527d59b6ecb96f433029ecc890d4492c5dce1
# betswirl                   0x94025780a1ab58868d9b2dbbb775f44b32e8e6e5
# juggernaut                 0x4e3642603a75528489c2d94f86e9507260d3c5a1
# cheems-inu-new             0xc11bf915db4b43714bc8d32bf83bf5ea53d40981
# qi-dao                     0xa56f9a54880afbc30cf29bb66d2d9adcdcaeadd6
# build                      0x5f018e73c185ab23647c82bd039e762813877f0e

# %% [markdown]
# ### Liquidity check

# %% [markdown]
# To derive a slippage threshold, consider an abstract univ2-like pool with $5m\$$ overall liquidity.
# I.e if pool has reserves $R_1$, $R_2$ and $p_1$ and $p_2$ are the correspondent tokens prices (in USD), then
# $$R_1p_1 = R_2p_2 = 2.5m \$$$
#
# Swapping $x$ token1 for token2 will result in the output amount $y$ such that
# $$R_1\cdot R_2 = (R_1 + x) \cdot (R_2 - y)$$
# $$y = \frac{R_2\cdot x}{R_1 + x}$$
# Then the delivery price will be
# $$p_d = \frac{y}{x} = \frac{R_2}{R_1 + x}$$
# The spot price may be estimated as a delivery price for relatively small input amount $x_0$
# $$p_s = \frac{y_0}{x_0} = \frac{R_2}{R_1 + x_0}$$
#
# Then the theoretical slippage for this pool will be
# $$slippage = \frac{p_d}{p_s} - 1 = \frac{R_1+x_0}{R_1+x} - 1 = \frac{p_1R_1+p_1x_0}{p_1R_1+p_1x}-1$$

# %%
url_0x = "https://avalanche.api.0x.org/swap/v1/quote"
header =  {'0x-api-key': decouple.config("ZEROEX_KEY")}

# %%
decimals = 18
slippages = []
for id, data in passed_q_and_non_q_checks.iterrows():
    try:
        query = {
            'buyToken': data['addr'],
            'sellToken': 'AVAX',
            'sellAmount': int(trade_value_tiny / tokens_market_data.loc['avalanche-2']['current_price'] * 10 ** decimals),
            'enableSlippageProtection':'true'
        }
        
        # spot price is calculated as a price for 100$ swap
        resp = requests.get(url_0x, params=query,headers=header)
        swap = resp.json()
        time.sleep(1)
        spot_price = float(swap['price'])
        
        query['sellAmount'] = int(trade_value / tokens_market_data.loc['avalanche-2']['current_price'] * 10 ** decimals)
        resp = requests.get(url_0x, params=query,headers=header)
        swap = resp.json()
        time.sleep(1)
        del_price = float(swap['price'])
        
        slippage = del_price / spot_price - 1
        slippages.append({
            'id': id,
            'spot_price': spot_price,
            'delivery_price': del_price,
            'slippage': slippage
        })
    except KeyError:
        print(id)
        continue
# Out:
# havven
# balancer
# axelar
# cartesi
# ankreth
# allianceblock-nexera
# idia
# realfevr
# oath
# euroe-stablecoin
# build
# spherium
# vnx-swiss-franc
# soul-swap
# shack
# bios
# nftearth

# %%
slippages_df = pd.DataFrame(slippages).sort_values('slippage',ascending=False).reset_index(drop=True)
slippages_df.head(20)
# Out:
#                              id    spot_price  delivery_price  slippage
# 0                   avalanche-2      1.000000        1.000000  0.000000
# 1      benqi-liquid-staked-avax      0.903940        0.903792 -0.000164
# 2                           joe     37.065786       36.306841 -0.020476
# 3        colony-avalanche-index      0.128656        0.118403 -0.079693
# 4                         benqi   1800.155099     1611.545564 -0.104774
# 5                      betswirl  18093.218639    16165.971705 -0.106518
# 6                      pangolin    498.266149      404.900102 -0.187382
# 7                     avalaunch     57.270288       46.493730 -0.188170
# 8                     chainlink      1.224377        0.959853 -0.216048
# 9                     yield-yak      0.035959        0.020152 -0.439584
# 10                         aave      0.138026        0.075666 -0.451800
# 11        dragon-crypto-argenti   1622.305399      780.576357 -0.518847
# 12                alpha-finance    118.996958       55.875877 -0.530443
# 13                   ampleforth      7.727135        3.210735 -0.584486
# 14               vector-finance    398.027797      159.538955 -0.599176
# 15  cosmic-universe-magic-token   1778.704477      699.487115 -0.606743
# 16                       colony    199.524758       66.812466 -0.665142
# 17                      nftrade    761.042373      211.747318 -0.721767
# 18          dragon-crypto-aurum      2.687437        0.731254 -0.727899
# 19               cheems-inu-new  27614.461070     6489.824235 -0.764985

# %%
# Writing to database
slippages_to_save = slippages_df[['id','slippage']].head(20)
asset_columns = db_funcs.convert_to_sql_strings(list(slippages_to_save['id']))
slippage_values = list(slippages_to_save['slippage'])
db_funcs.insert_values(db_key_date,asset_columns,slippage_values,db_liquidity_table)

# %%
def check_avg_liquidity(date_delta):
    start_date = str(datetime.date.fromisoformat(db_key_date) - datetime.timedelta(days=date_delta))
    dataframe = pd.read_sql(f'Select * from {db_liquidity_table} where date >= ? ',db_funcs.create_connection(db_funcs.db),index_col='date',parse_dates=['date'],params=[start_date])
    dataframe = dataframe.ewm(span=3).mean().iloc[-1]
    dataframe = dataframe[dataframe > max_slippage]
    dataframe.index = db_funcs.convert_from_sql_strings(list(dataframe.index))
    return dataframe, list(dataframe.index)

avg_liq_dataframe ,include_list = check_avg_liquidity(liquidity_consistency)
avg_liq_dataframe
# Out:
# benqi-liquid-staked-avax   -0.000155
# avalanche-2                 0.000000
# joe                        -0.020915
# Name: 2023-10-01 00:00:00, dtype: float64

# %%
qualified_assets = passed_q_and_non_q_checks.query('index in @include_list')
qualified_assets
# Out:
#                                               name symbol    market_cap  \
# id
# avalanche-2                              Avalanche   AVAX  3.450144e+09
# joe                                            JOE    JOE  8.938757e+07
# benqi-liquid-staked-avax  BENQI Liquid Staked AVAX  SAVAX  7.074822e+07
#
#                           market_cap_rank  current_price  total_supply  \
# id
# avalanche-2                          23.0       9.730000  4.315704e+08
# joe                                 255.0       0.261539  4.764376e+08
# benqi-liquid-staked-avax            319.0      10.770000  6.561828e+06
#
#                           circulating_supply  \
# id
# avalanche-2                     3.541961e+08
# joe                             3.414594e+08
# benqi-liquid-staked-avax        6.561828e+06
#
#                                                                 addr
# id
# avalanche-2               0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be

# %% [markdown]
# ### Marketcap ranking & filtering

# %%
chosen_tokens = qualified_assets.sort_values("market_cap", ascending=False)

# %% [markdown]
# ## Weighting

# %% [markdown]
# **Weighting requirements**
# * The maximum weight any one token can have is 50%.
# * All excess weight is proportionally redistributed to all uncapped tokens.
# * Any asset with a weight below 0.5% will be removed from the index.

# %% [markdown]
# ### Weight mcaps

# %%
# exclude savax from weighting since it should be a part of avax weight
if 'benqi-liquid-staked-avax' in chosen_tokens.index:
    chosen_tokens_ex_savax = chosen_tokens.drop('benqi-liquid-staked-avax')
    weights = chosen_tokens_ex_savax['market_cap'].div(chosen_tokens_ex_savax['market_cap'].sum())
else:
    weights = chosen_tokens['market_cap'].div(chosen_tokens['market_cap'].sum())

# %% [markdown]
# ### Adjust weights

# %% [markdown]
# This process adjusts weights to adhere to the weight constraints described in our methodology. In addition the `remove_tiny_weights` function checks for any assets with a weight below the minimum threshold of $0.5\%$ and proportionally increases all remaining weights (which are $> 0.5\%$). Note that after this procedure readjusting weights to respect maximum may be needed.

# %%
def adjust_weights(weights, max_weight):
    w = weights.copy()
    
    while (w > max_weight).any(axis=None):
        w[w > max_weight] = max_weight
        c = 1 - w.sum()
        w_less = w[w < max_weight]
        w[(w < max_weight) & (w > 0)] += w_less.div(w_less.sum()).mul(c)
    
    return w

# %%
def remove_tiny_weights(weights, min_weight):
    w = weights.copy()
    
    w[w < min_weight] = 0
    w = w.div(w.sum())
    
    return w

# %%
adjusted_weights = adjust_weights(weights, max_weight=max_weight) 
adjusted_weights = remove_tiny_weights(adjusted_weights, min_weight=min_weight)
adjusted_weights = adjust_weights(adjusted_weights, max_weight=max_weight)

# %% [markdown]
# ### Split AVAX

# %%
if 'avalanche-2' and 'benqi-liquid-staked-avax' in chosen_tokens.index:
    
    adjusted_weights['benqi-liquid-staked-avax'] = adjusted_weights['avalanche-2'] * avax_to_savax_split
    adjusted_weights['avalanche-2'] = adjusted_weights['avalanche-2'] * (1 - avax_to_savax_split)

adjusted_weights =  adjusted_weights.sort_values(ascending = False)

# %% [markdown]
# ### Convert weights to the [1, 255] scale

# %% [markdown]
# On the contract side weights are integer numbers from the interval $[1, 255]$ with total sum $255$, so it's needed to convert retrieved weights to this format.
#
# Note that one can't just round weights to integers after scaling, since it doesn't guarantee that their sum will be $255$. To fix that firstly floor function is applied to the weights and then $1$ is being added to the $k$ weights with largest fractional parts.

# %%
def convert_weights(weights):
    w_scaled = weights * 255
    w_res = np.floor(w_scaled).astype(int)    
    remainders = w_scaled - w_res    
    k = round(remainders.sum())
    w_below_max = w_res[w_res<128]
    for i in range(k):
        w_below_max[i] +=1
    for i in w_below_max.index:
        w_res[i] = w_below_max[i]
    return w_res

# %%
converted_weights = convert_weights(adjusted_weights)
# Out:
# /var/folders/4t/6j5ypx_s6r771shjr5dcct5w0000gn/T/ipykernel_6932/3538882253.py:8: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /var/folders/4t/6j5ypx_s6r771shjr5dcct5w0000gn/T/ipykernel_6932/3538882253.py:8: FutureWarning:
#
# Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`

# %% [markdown]
# ## Summary table

# %%
cai = pd.DataFrame()
cai.index = chosen_tokens.index
cai['name'] = chosen_tokens['name']
cai['symbol'] = chosen_tokens['symbol']
cai['market_cap'] = chosen_tokens['market_cap']
cai['price'] = chosen_tokens['current_price']
cai['weight'] = adjusted_weights
cai['weight_converted'] = converted_weights
cai['address'] = chosen_tokens['addr']

cai = cai[cai['weight'] > 0]
cai = cai.sort_values("market_cap", ascending=False)
cai
# Out:
#                                               name symbol    market_cap  \
# id
# avalanche-2                              Avalanche   AVAX  3.450144e+09
# joe                                            JOE    JOE  8.938757e+07
# benqi-liquid-staked-avax  BENQI Liquid Staked AVAX  SAVAX  7.074822e+07
#
#                               price  weight  weight_converted  \
# id
# avalanche-2                9.730000     0.2                51
# joe                        0.261539     0.5               128
# benqi-liquid-staked-avax  10.770000     0.3                76
#
#                                                              address
# id
# avalanche-2               0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be

# %%
# Add assets and weights to database
db_assets = db_funcs.convert_to_sql_strings(list(cai.index))
db_weights = list(cai['weight'])
db_funcs.insert_values(db_key_date,db_assets,db_weights,db_benchmark_table)

# %%
#Querying current contract to ascertain which assets will be dropped

cai_token_address = '0x48f88A3fE843ccb0b5003e70B4192c1d7448bEf0'
ia_contract = web3_object.eth.contract(address=cai_token_address,abi=index_anatomy)
addresses, weights = ia_contract.functions.anatomy().call()


for address in addresses:
    address = address.lower()
    if address not in list(cai['address']):
        data = tokens_market_data[tokens_market_data['addr']== address]
        cai.loc[data.index[0]] = [data['name'][0],data['symbol'][0],data['market_cap'][0],data['current_price'][0],0,0,address]

cai
# Out:
#                                               name symbol    market_cap  \
# id
# avalanche-2                              Avalanche   AVAX  3.450144e+09
# joe                                            JOE    JOE  8.938757e+07
# benqi-liquid-staked-avax  BENQI Liquid Staked AVAX  SAVAX  7.074822e+07
#
#                               price  weight  weight_converted  \
# id
# avalanche-2                9.730000     0.2                51
# joe                        0.261539     0.5               128
# benqi-liquid-staked-avax  10.770000     0.3                76
#
#                                                              address
# id
# avalanche-2               0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be

# %%
zipped_assets = list(zip(list(cai['address']),list(cai['weight_converted'])))
sorted_assets = sorted(zipped_assets,key = lambda x: int(x[0],base=0) )

asset_string = ''
for i in sorted_assets:
    asset_string += f'{i[0]},'
asset_string = asset_string[:-1]
print(asset_string)
print([x[1] for x in sorted_assets])
# Out:
# 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,0xb31f66aa3c1e785363f0875a1b74e27b85fd66c7
# [76, 128, 51]
