# %% [markdown]
# ## CAI - Colony Avalanche Index - Rebalancing data for October 2025

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import decouple
import sys
sys.path.append('../')
from methodology import MethodologyProd
from pycoingecko import CoinGeckoAPI
key =  decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key=key)

# %% [markdown]
# ## Index Variables

# %%
date = '2025-10-01'
min_mcap =  0.05e8
min_weight = 0.005
max_weight = 0.3
circ_supply_threshold = 0.3
liveness_threshold = 180 # In days
liquidity_consistency = 90 # In days
coingecko_category = ["avalanche-ecosystem"]

# Calculating max slippage based on liquidity threshold
liq = 2*1e6
liq_os = liq / 2 # one-side liquidity 
trade_value_tiny = 1e2
trade_value = 1e5
max_slippage = (liq_os + trade_value_tiny) / (liq_os + trade_value) - 1
# round to the nearest .01
max_slippage = round(max_slippage, 2)

# Dataframes to remove
stablecoins = pd.DataFrame(cg.get_coins_markets('usd',category='stablecoins')).set_index('id')
ctokens = pd.DataFrame(cg.get_coins_markets('usd',category='compound-tokens')).set_index('id')
atokens = pd.DataFrame(cg.get_coins_markets('usd',category='aave-tokens')).set_index('id')

methodology_class = MethodologyProd(
                                date,
                                1,
                                "avalanche",
                                "0x48f88A3fE843ccb0b5003e70B4192c1d7448bEf0",
                                "cai_benchmark_data",
                                "cai_liquidities",
                                min_mcap,
                                min_weight,
                                max_weight,
                                100000,
                                255,
                                circ_supply_threshold,
                                liveness_threshold,
                                liquidity_consistency,
                                -0.22,
                                coingecko_category)

# %% [markdown]
# ## Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data at least 6 months prior to the date of inclusion in the index.
#     1. The project should have a token that is native to Avalanche. This excludes wrapped variants, where the underlying tokens are locked on an alt-L1.
#     1. The project should be a going concern, with a dedicated team actively building, supporting and maintaining the project.
#     1. No rebasing or deflationary tokens.
#     1. The project must be widely considered to be building a useful protocol or product. Projects that have ponzi characteristics at the core of their offering will not be considered.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project’s protocol or product must have significant usage.
#     <br>
# 1. **Pricing requirements**
#     1. Token should have a Chainlink price feed to allow for manipulation resistant pricing.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 30% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The token must have shown consistent DeFi liquidity on Avalanche.
#     1. The token must experience less than 15% price impact for a $100k trade in both directions.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.

# %% [markdown]
# ## Run Methodology

# %%
results,liquidity = methodology_class.main(
    single_chain="avalanche",
    df_to_remove=[stablecoins,ctokens,atokens],
    ids_to_replace=[["avalanche-2"],["benqi-liquid-staked-avax"]],
    remove_category_assets=['wrapped-bitcoin',"gmx","euro-coin","bitcoin-avalanche-bridged-btc-b","benqi-liquid-staked-avax","pangolin","chainlink","stargate-finance","avalanche-bridged-weth-avalanche",
                            "tether-avalanche-bridged-usdt-e","usd-coin-avalanche-bridged-usdc-e",
                            "wrapped-avax","avalanche-old-bridged-wbtc-avalanche","aave","avax-has-no-chill"
                            ,"avant-staked-usd","kepler","ethena-staked-usde"],
    values_to_update=[{'id':'pangolin','category':'total_supply','value':230000000},
                      {'id':'benqi-liquid-staked-avax','category':'market_cap','value':161_000_000},
                      {'id':'benqi-liquid-staked-avax','category':'symbol','value':"sAVAX"}
                      ],
    enable_liquidity_score=True,
    weight_split_data= {"asset_to_split":"benqi-liquid-staked-avax","asset_to_receive":"gogopool-ggavax","split_ratio":0.5},
    individual_asset_weight={"coq-inu":0.05}

    )
liquidity
# Out:
# Excluding staked-stream-usd, pricing data available only for 5 < 180 days
# Excluding wrapped-savings-rusd, pricing data available only for 29 < 180 days
# Excluding vaneck-treasury-fund, pricing data available only for 127 < 180 days
# Excluding blackhole, pricing data available only for 79 < 180 days
# Excluding avalanche-bridged-gho-avalanche, pricing data available only for 75 < 180 days
# Excluding staked-uty, pricing data available only for 71 < 180 days
# Excluding yield-btc-b, pricing data available only for 90 < 180 days
# Table created successfully
# Table created successfully
# pepe on avalanche returned an invalid API response
# pepe recorded no valid response across any platform
# ethena on avalanche returned an invalid API response
# ethena recorded no valid response across any platform
# blackrock-usd-institutional-digital-liquidity-fund on avalanche returned an invalid API response
# blackrock-usd-institutional-digital-liquidity-fund recorded no valid response across any platform
# solv-btc on avalanche returned an invalid API response
# solv-btc recorded no valid response across any platform
# spx6900 on avalanche returned an invalid API response
# spx6900 recorded no valid response across any platform
# binance-peg-dogecoin on avalanche returned an invalid API response
# binance-peg-dogecoin recorded no valid response across any platform
# havven on avalanche returned an invalid API response
# havven recorded no valid response across any platform
# superfarm on avalanche returned an invalid API response
# superfarm recorded no valid response across any platform
# solv-protocol-solvbtc-bbn on avalanche returned an invalid API response
# solv-protocol-solvbtc-bbn recorded no valid response across any platform
# mog-coin on avalanche returned an invalid API response
# mog-coin recorded no valid response across any platform
# 0x on avalanche returned an invalid API response
# 0x recorded no valid response across any platform
# ankr on avalanche returned an invalid API response
# ankr recorded no valid response across any platform
# apollo-diversified-credit-securitize-fund on avalanche returned an invalid API response
# apollo-diversified-credit-securitize-fund recorded no valid response across any platform
# orderly-network on avalanche returned an invalid API response
# orderly-network recorded no valid response across any platform
# wilder-world on avalanche returned an invalid API response
# wilder-world recorded no valid response across any platform
# cartesi on avalanche returned an invalid API response
# cartesi recorded no valid response across any platform
# staked-frax on avalanche returned an invalid API response
# staked-frax recorded no valid response across any platform
# mythos on avalanche returned an invalid API response
# mythos recorded no valid response across any platform
# ankreth on avalanche returned an invalid API response
# ankreth recorded no valid response across any platform
# metamui on avalanche returned an invalid API response
# metamui recorded no valid response across any platform
# telos on avalanche returned an invalid API response
# telos recorded no valid response across any platform
# fbomb on avalanche returned an invalid API response
# fbomb recorded no valid response across any platform
# sweatcoin on avalanche returned an invalid API response
# sweatcoin recorded no valid response across any platform
# vertical-ai on avalanche returned an invalid API response
# vertical-ai recorded no valid response across any platform
# idia on avalanche returned an invalid API response
# idia recorded no valid response across any platform
# aleph on avalanche returned an invalid API response
# aleph recorded no valid response across any platform
# miracle-play on avalanche returned an invalid API response
# miracle-play recorded no valid response across any platform
# allianceblock-nexera on avalanche returned an invalid API response
# allianceblock-nexera recorded no valid response across any platform
# tarot-2 on avalanche returned an invalid API response
# tarot-2 recorded no valid response across any platform
# vnx-swiss-franc on avalanche returned an invalid API response
# vnx-swiss-franc recorded no valid response across any platform
# yield-yak did not meet the average three month liquidity threshold
# ampleforth did not meet the average three month liquidity threshold
# trustswap did not meet the average three month liquidity threshold
# snowbank did not meet the average three month liquidity threshold
# playa3ull-games-2 did not meet the average three month liquidity threshold
# osaka-protocol did not meet the average three month liquidity threshold
# dexalot did not meet the average three month liquidity threshold
# beam-2 did not meet the average three month liquidity threshold
# avalanche-bridged-dai-avalanche did not meet the average three month liquidity threshold
# alvara-protocol did not meet the average three month liquidity threshold
# ket did not meet the average three month liquidity threshold
# orange-2 did not meet the average three month liquidity threshold
# nya did not meet the average three month liquidity threshold
# xsgd did not meet the average three month liquidity threshold
# the-arena did not meet the average three month liquidity threshold
#                                  avalanche optimal chain  best slippage  \
# id
# benqi-liquid-staked-avax         -0.001135     avalanche      -0.001135
# gogopool-ggavax                  -0.001161     avalanche      -0.001161
# coq-inu                          -0.089567     avalanche      -0.089567
# joe                              -0.102831     avalanche      -0.102831
# benqi                            -0.121152     avalanche      -0.121152
# colony                           -0.131346     avalanche      -0.131346
# avalaunch                        -0.131881     avalanche      -0.131881
# gogopool                         -0.164098     avalanche      -0.164098
# dexalot                          -0.187998     avalanche      -0.187998
# yield-yak                        -0.221828          None      -0.221828
# beam-2                           -0.289068          None      -0.289068
# nya                              -0.351825          None      -0.351825
# playa3ull-games-2                -0.426107          None      -0.426107
# avalanche-bridged-dai-avalanche  -0.470060          None      -0.470060
# ampleforth                       -0.514882          None      -0.514882
# orange-2                         -0.652306          None      -0.652306
# alvara-protocol                  -0.730248          None      -0.730248
# trustswap                        -0.768438          None      -0.768438
# osaka-protocol                   -0.855534          None      -0.855534
# the-arena                        -0.926823          None      -0.926823
# snowbank                         -0.940421          None      -0.940421
# spell-token                      -0.941480          None      -0.941480
# synapse-2                        -0.961873          None      -0.961873
# xen-crypto                       -0.981764          None      -0.981764
# sushi                            -0.985927          None      -0.985927
# ket                              -0.986028          None      -0.986028
# frax-share                       -0.991203          None      -0.991203
# beta-finance                     -0.996413          None      -0.996413
# uniswap                          -0.996600          None      -0.996600
# alpha-finance                    -0.997024          None      -0.997024
# heyanon                          -0.997046          None      -0.997046
# axelar                           -0.997806          None      -0.997806
# woo-network                      -0.998224          None      -0.998224
# balancer                         -0.998483          None      -0.998483
# yusd-stablecoin                  -0.998576          None      -0.998576
# 1inch                            -0.998846          None      -0.998846
# dextf                            -0.999522          None      -0.999522
# deapcoin                         -0.999535          None      -0.999535
# basic-attention-token            -0.999547          None      -0.999547
# euler                            -0.999645          None      -0.999645
# wagmi-2                          -0.999702          None      -0.999702
# kyber-network-crystal            -0.999714          None      -0.999714
# yearn-finance                    -0.999825          None      -0.999825
# the-graph                        -0.999848          None      -0.999848
# bilira                           -0.999871          None      -0.999871
# insure                           -0.999876          None      -0.999876
# wrapped-eeth                     -0.999895          None      -0.999895
# uma                              -0.999900          None      -0.999900
# vicicoin                         -0.999900          None      -0.999900
# compound-governance-token        -0.999900          None      -0.999900
# orbs                             -0.999901          None      -0.999901
#
#                                  optimal slippage best slippage chain  \
# id
# benqi-liquid-staked-avax                -0.001135           avalanche
# gogopool-ggavax                         -0.001161           avalanche
# coq-inu                                 -0.089567           avalanche
# joe                                     -0.102831           avalanche
# benqi                                   -0.121152           avalanche
# colony                                  -0.131346           avalanche
# avalaunch                               -0.131881           avalanche
# gogopool                                -0.164098           avalanche
# dexalot                                 -0.187998           avalanche
# yield-yak                               -0.221828           avalanche
# beam-2                                  -0.289068           avalanche
# nya                                     -0.351825           avalanche
# playa3ull-games-2                       -0.426107           avalanche
# avalanche-bridged-dai-avalanche         -0.470060           avalanche
# ampleforth                              -0.514882           avalanche
# orange-2                                -0.652306           avalanche
# alvara-protocol                         -0.730248           avalanche
# trustswap                               -0.768438           avalanche
# osaka-protocol                          -0.855534           avalanche
# the-arena                               -0.926823           avalanche
# snowbank                                -0.940421           avalanche
# spell-token                             -0.941480           avalanche
# synapse-2                               -0.961873           avalanche
# xen-crypto                              -0.981764           avalanche
# sushi                                   -0.985927           avalanche
# ket                                     -0.986028           avalanche
# frax-share                              -0.991203           avalanche
# beta-finance                            -0.996413           avalanche
# uniswap                                 -0.996600           avalanche
# alpha-finance                           -0.997024           avalanche
# heyanon                                 -0.997046           avalanche
# axelar                                  -0.997806           avalanche
# woo-network                             -0.998224           avalanche
# balancer                                -0.998483           avalanche
# yusd-stablecoin                         -0.998576           avalanche
# 1inch                                   -0.998846           avalanche
# dextf                                   -0.999522           avalanche
# deapcoin                                -0.999535           avalanche
# basic-attention-token                   -0.999547           avalanche
# euler                                   -0.999645           avalanche
# wagmi-2                                 -0.999702           avalanche
# kyber-network-crystal                   -0.999714           avalanche
# yearn-finance                           -0.999825           avalanche
# the-graph                               -0.999848           avalanche
# bilira                                  -0.999871           avalanche
# insure                                  -0.999876           avalanche
# wrapped-eeth                            -0.999895           avalanche
# uma                                     -0.999900           avalanche
# vicicoin                                -0.999900           avalanche
# compound-governance-token               -0.999900           avalanche
# orbs                                    -0.999901           avalanche
#
#                                  liquidity score
# id
# benqi-liquid-staked-avax              100.000000
# gogopool-ggavax                        99.997478
# coq-inu                                91.234406
# joe                                    89.919644
# benqi                                  88.103641
# colony                                 87.093221
# avalaunch                              87.040180
# gogopool                               83.846751
# dexalot                                81.477709
# yield-yak                              78.124459
# beam-2                                 71.459437
# nya                                    65.238807
# playa3ull-games-2                      57.875773
# avalanche-bridged-dai-avalanche        53.519044
# ampleforth                             49.076217
# orange-2                               35.454418
# alvara-protocol                        27.728583
# trustswap                              23.943104
# osaka-protocol                         15.309947
# the-arena                               8.243643
# snowbank                                6.895739
# spell-token                             6.790764
# synapse-2                               4.769378
# xen-crypto                              2.797719
# sushi                                   2.385069
# ket                                     2.375068
# frax-share                              1.862139
# beta-finance                            1.345742
# uniswap                                 1.327198
# alpha-finance                           1.285136
# heyanon                                 1.282960
# axelar                                  1.207586
# woo-network                             1.166170
# balancer                                1.140490
# yusd-stablecoin                         1.131272
# 1inch                                   1.104545
# dextf                                   1.037522
# deapcoin                                1.036240
# basic-attention-token                   1.035026
# euler                                   1.025323
# wagmi-2                                 1.019714
# kyber-network-crystal                   1.018493
# yearn-finance                           1.007532
# the-graph                               1.005183
# bilira                                  1.002894
# insure                                  1.002441
# wrapped-eeth                            1.000515
# uma                                     1.000055
# vicicoin                                1.000053
# compound-governance-token               1.000051
# orbs                                    1.000000

# %% [markdown]
# ## Show Results

# %%
results
# Out:
#                           symbol   market_cap    weight  weight_converted  \
# joe                          JOE   66483038.0  0.267826                69
# benqi                         QI   58049354.0  0.229128                59
# benqi-liquid-staked-avax   sAVAX  161000000.0  0.150000                39
# gogopool-ggavax           STAVAX   31292999.0  0.150000                38
# gogopool                     GGP   16806571.0  0.063132                16
# avalaunch                   XAVA   13730060.0  0.053540                13
# coq-inu                      COQ   32905617.0  0.050000                12
# colony                       CLY    9322015.0  0.036373                 9
#
#                                                              address  \
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi                     0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# gogopool-ggavax           0xa25eaf2906fa1a3a13edac9b9657108af7b703e3
# gogopool                  0x69260b9483f9871ca57f81a90d91e2f96c2cd11d
# avalaunch                 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# coq-inu                   0x420fca0121dc28039145009570975747295f2329
# colony                    0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
#
#                          blockchain
# joe                       avalanche
# benqi                     avalanche
# benqi-liquid-staked-avax  avalanche
# gogopool-ggavax           avalanche
# gogopool                  avalanche
# avalaunch                 avalanche
# coq-inu                   avalanche
# colony                    avalanche

# %% [markdown]
# ## Contract Output

# %%
methodology_class.output_for_contract()
# Out:
# 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,0x420fca0121dc28039145009570975747295f2329,0x69260b9483f9871ca57f81a90d91e2f96c2cd11d,0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,0x8729438eb15e2c8b576fcc6aecda6a148776c0f5,0xa25eaf2906fa1a3a13edac9b9657108af7b703e3,0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4,0xec3492a2508ddf4fdc0cd76f31f340b30d1793e6
# 39,12,16,69,59,38,13,9
