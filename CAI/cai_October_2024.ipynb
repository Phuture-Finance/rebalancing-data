# %% [markdown]
# ## CAI - Colony Avalanche Index - Rebalancing data for September 2024

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import decouple
import sys
sys.path.append('../')
from methodology import MethodologyProd
from pycoingecko import CoinGeckoAPI
key =  decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key=key)

# %% [markdown]
# ## Index Variables

# %%
date = '2024-10-01'
min_mcap =  0.1e8
min_weight = 0.005
max_weight = 0.5
circ_supply_threshold = 0.3
liveness_threshold = 180 # In days
liquidity_consistency = 90 # In days
coingecko_category = ["avalanche-ecosystem"]

# Calculating max slippage based on liquidity threshold
liq = 2*1e6
liq_os = liq / 2 # one-side liquidity 
trade_value_tiny = 1e2
trade_value = 1e5
max_slippage = (liq_os + trade_value_tiny) / (liq_os + trade_value) - 1
# round to the nearest .01
max_slippage = round(max_slippage, 2)

# Dataframes to remove
stablecoins = pd.DataFrame(cg.get_coins_markets('usd',category='stablecoins')).set_index('id')
ctokens = pd.DataFrame(cg.get_coins_markets('usd',category='compound-tokens')).set_index('id')
atokens = pd.DataFrame(cg.get_coins_markets('usd',category='aave-tokens')).set_index('id')

methodology_class = MethodologyProd(
                                date,
                                1,
                                "avalanche",
                                "0x48f88A3fE843ccb0b5003e70B4192c1d7448bEf0",
                                "cai_benchmark_data",
                                "cai_liquidities",
                                min_mcap,
                                min_weight,
                                max_weight,
                                100000,
                                255,
                                circ_supply_threshold,
                                liveness_threshold,
                                liquidity_consistency,
                                -0.13,
                                coingecko_category)

# %% [markdown]
# ## Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data at least 6 months prior to the date of inclusion in the index.
#     1. The project should have a token that is native to Avalanche. This excludes wrapped variants, where the underlying tokens are locked on an alt-L1.
#     1. The project should be a going concern, with a dedicated team actively building, supporting and maintaining the project.
#     1. No rebasing or deflationary tokens.
#     1. The project must be widely considered to be building a useful protocol or product. Projects that have ponzi characteristics at the core of their offering will not be considered.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project’s protocol or product must have significant usage.
#     <br>
# 1. **Pricing requirements**
#     1. Token should have a Chainlink price feed to allow for manipulation resistant pricing.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 30% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The token should have in aggregate at least $2mm of onchain liquidity across Trader Joe, Platypus, Pangolin.
#     1. The token must have shown consistent DeFi liquidity on Avalanche.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.

# %% [markdown]
# ## Run Methodology

# %%
results,liquidity = methodology_class.main(
    single_chain="avalanche",
    df_to_remove=[stablecoins,ctokens,atokens],
    ids_to_replace=[["avalanche-2"],["benqi-liquid-staked-avax"]],
    remove_category_assets=['wrapped-bitcoin',"gmx","euro-coin","bitcoin-avalanche-bridged-btc-b","benqi-liquid-staked-avax"],
    values_to_update=[{'id':'pangolin','category':'total_supply','value':230000000},
                      {'id':'benqi-liquid-staked-avax','category':'market_cap','value':20000000000},
                      {'id':'benqi-liquid-staked-avax','category':'symbol','value':"sAVAX"}
                      ],
    enable_liquidity_score=True

    )
liquidity
# Out:
# Excluding avalanche-bridged-weth-avalanche, pricing data available only for 50 < 180 days
# Excluding avalanche-old-bridged-wbtc-avalanche, pricing data available only for 61 < 180 days
# Excluding avalanche-bridged-dai-avalanche, pricing data available only for 45 < 180 days
# Table created successfully
# Table created successfully
# solv-btc on avalanche returned an invalid API response
# solv-btc recorded no valid response across any platform
# axelar on avalanche returned an invalid API response
# axelar recorded no valid response across any platform
# havven on avalanche returned an invalid API response
# havven recorded no valid response across any platform
# ankr on avalanche returned an invalid API response
# ankr recorded no valid response across any platform
# telos on avalanche returned an invalid API response
# telos recorded no valid response across any platform
# cartesi on avalanche returned an invalid API response
# cartesi recorded no valid response across any platform
# kyber-network-crystal on avalanche returned an invalid API response
# kyber-network-crystal recorded no valid response across any platform
# ampleforth on avalanche returned an invalid API response
# ampleforth recorded no valid response across any platform
# ankreth on avalanche returned an invalid API response
# ankreth recorded no valid response across any platform
# allianceblock-nexera on avalanche returned an invalid API response
# allianceblock-nexera recorded no valid response across any platform
# miracle-play on avalanche returned an invalid API response
# miracle-play recorded no valid response across any platform
# idia on avalanche returned an invalid API response
# idia recorded no valid response across any platform
# ox-fun on avalanche returned an invalid API response
# ox-fun recorded no valid response across any platform
# tarot-2 on avalanche returned an invalid API response
# tarot-2 recorded no valid response across any platform
# avalaunch did not meet the average three month liquidity threshold
# chainlink did not meet the average three month liquidity threshold
# aave did not meet the average three month liquidity threshold
# ampleforth did not meet the average three month liquidity threshold
# trustswap did not meet the average three month liquidity threshold
# snowbank did not meet the average three month liquidity threshold
# colony did not meet the average three month liquidity threshold
# xana did not meet the average three month liquidity threshold
# playa3ull-games-2 did not meet the average three month liquidity threshold
# osaka-protocol did not meet the average three month liquidity threshold
# spell-token did not meet the average three month liquidity threshold
# synapse-2 did not meet the average three month liquidity threshold
# dexalot did not meet the average three month liquidity threshold
# gamer-arena did not meet the average three month liquidity threshold
# defi-kingdoms did not meet the average three month liquidity threshold
# meld-2 did not meet the average three month liquidity threshold
# aleph did not meet the average three month liquidity threshold
# gogopool did not meet the average three month liquidity threshold
# beam-2 did not meet the average three month liquidity threshold
# Dropping coq-inu because a price feed is unavailable
# Dropping usd-coin-avalanche-bridged-usdc-e because a price feed is unavailable
# Dropping gogopool-ggavax because a price feed is unavailable
#                                    avalanche optimal chain  best slippage  \
# id
# usd-coin-avalanche-bridged-usdc-e  -0.000090     avalanche      -0.000090
# gogopool-ggavax                    -0.001556     avalanche      -0.001556
# benqi-liquid-staked-avax           -0.013207     avalanche      -0.013207
# benqi                              -0.015943     avalanche      -0.015943
# joe                                -0.020048     avalanche      -0.020048
# coq-inu                            -0.020470     avalanche      -0.020470
# pangolin                           -0.079363     avalanche      -0.079363
# gogopool                           -0.114365     avalanche      -0.114365
# avalaunch                          -0.135689          None      -0.135689
# aave                               -0.265183          None      -0.265183
# colony                             -0.295712          None      -0.295712
# playa3ull-games-2                  -0.348317          None      -0.348317
# gamer-arena                        -0.423842          None      -0.423842
# chainlink                          -0.496855          None      -0.496855
# osaka-protocol                     -0.497404          None      -0.497404
# beam-2                             -0.527853          None      -0.527853
# dexalot                            -0.530388          None      -0.530388
# trustswap                          -0.768672          None      -0.768672
# meld-2                             -0.888131          None      -0.888131
# spell-token                        -0.897579          None      -0.897579
# defi-kingdoms                      -0.921287          None      -0.921287
# synapse-2                          -0.937087          None      -0.937087
# snowbank                           -0.950125          None      -0.950125
# xen-crypto                         -0.974184          None      -0.974184
# sushi                              -0.982692          None      -0.982692
# beta-finance                       -0.984571          None      -0.984571
# baklava                            -0.988156          None      -0.988156
# spookyswap                         -0.991145          None      -0.991145
# frax-share                         -0.992846          None      -0.992846
# alpha-finance                      -0.995133          None      -0.995133
# balancer                           -0.996936          None      -0.996936
# uniswap                            -0.997340          None      -0.997340
# woo-network                        -0.997762          None      -0.997762
# 1inch                              -0.999008          None      -0.999008
# deapcoin                           -0.999554          None      -0.999554
# basic-attention-token              -0.999601          None      -0.999601
# dextf                              -0.999661          None      -0.999661
# insure                             -0.999832          None      -0.999832
# yearn-finance                      -0.999834          None      -0.999834
# the-graph                          -0.999843          None      -0.999843
# uma                                -0.999900          None      -0.999900
# orbs                               -0.999900          None      -0.999900
# compound-governance-token          -0.999900          None      -0.999900
# maker                              -0.999900          None      -0.999900
# 0x                                 -0.999900          None      -0.999900
# aleph                              -1.000000          None      -1.000000
#
#                                    optimal slippage best slippage chain  \
# id
# usd-coin-avalanche-bridged-usdc-e         -0.000090           avalanche
# gogopool-ggavax                           -0.001556           avalanche
# benqi-liquid-staked-avax                  -0.013207           avalanche
# benqi                                     -0.015943           avalanche
# joe                                       -0.020048           avalanche
# coq-inu                                   -0.020470           avalanche
# pangolin                                  -0.079363           avalanche
# gogopool                                  -0.114365           avalanche
# avalaunch                                 -0.135689           avalanche
# aave                                      -0.265183           avalanche
# colony                                    -0.295712           avalanche
# playa3ull-games-2                         -0.348317           avalanche
# gamer-arena                               -0.423842           avalanche
# chainlink                                 -0.496855           avalanche
# osaka-protocol                            -0.497404           avalanche
# beam-2                                    -0.527853           avalanche
# dexalot                                   -0.530388           avalanche
# trustswap                                 -0.768672           avalanche
# meld-2                                    -0.888131           avalanche
# spell-token                               -0.897579           avalanche
# defi-kingdoms                             -0.921287           avalanche
# synapse-2                                 -0.937087           avalanche
# snowbank                                  -0.950125           avalanche
# xen-crypto                                -0.974184           avalanche
# sushi                                     -0.982692           avalanche
# beta-finance                              -0.984571           avalanche
# baklava                                   -0.988156           avalanche
# spookyswap                                -0.991145           avalanche
# frax-share                                -0.992846           avalanche
# alpha-finance                             -0.995133           avalanche
# balancer                                  -0.996936           avalanche
# uniswap                                   -0.997340           avalanche
# woo-network                               -0.997762           avalanche
# 1inch                                     -0.999008           avalanche
# deapcoin                                  -0.999554           avalanche
# basic-attention-token                     -0.999601           avalanche
# dextf                                     -0.999661           avalanche
# insure                                    -0.999832           avalanche
# yearn-finance                             -0.999834           avalanche
# the-graph                                 -0.999843           avalanche
# uma                                       -0.999900           avalanche
# orbs                                      -0.999900           avalanche
# compound-governance-token                 -0.999900           avalanche
# maker                                     -0.999900           avalanche
# 0x                                        -0.999900           avalanche
# aleph                                     -1.000000           avalanche
#
#                                    liquidity score
# id
# usd-coin-avalanche-bridged-usdc-e       100.000000
# gogopool-ggavax                          99.854885
# benqi-liquid-staked-avax                 98.701317
# benqi                                    98.430407
# joe                                      98.023968
# coq-inu                                  97.982193
# pangolin                                 92.151323
# gogopool                                 88.685781
# avalaunch                                86.574484
# aave                                     73.753479
# colony                                   70.730800
# playa3ull-games-2                        65.522417
# gamer-arena                              58.044810
# chainlink                                50.815844
# osaka-protocol                           50.761476
# beam-2                                   47.746770
# dexalot                                  47.495732
# trustswap                                23.903512
# meld-2                                   12.075993
# spell-token                              11.140620
# defi-kingdoms                             8.793272
# synapse-2                                 7.228905
# snowbank                                  5.938110
# xen-crypto                                3.555979
# sushi                                     2.713655
# beta-finance                              2.527637
# baklava                                   2.172634
# spookyswap                                1.876769
# frax-share                                1.708284
# alpha-finance                             1.481925
# balancer                                  1.303326
# uniswap                                   1.263374
# woo-network                               1.221533
# 1inch                                     1.098199
# deapcoin                                  1.044110
# basic-attention-token                     1.039551
# dextf                                     1.033575
# insure                                    1.016662
# yearn-finance                             1.016448
# the-graph                                 1.015591
# uma                                       1.009905
# orbs                                      1.009903
# compound-governance-token                 1.009901
# maker                                     1.009901
# 0x                                        1.009901
# aleph                                     1.000000

# %% [markdown]
# ## Show Results

# %%
results
# Out:
#                              symbol   market_cap    weight  weight_converted  \
# benqi-liquid-staked-avax      sAVAX  20000000000  0.500000               128
# joe                             JOE    112418689  0.255414                66
# benqi                            QI     60970554  0.139099                35
# pangolin                        PNG     49388659  0.105488                26
# avalaunch                 Avalaunch            0  0.000000                 0
#
#                                                              address  \
# benqi-liquid-staked-avax  0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be
# joe                       0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd
# benqi                     0x8729438eb15e2c8b576fcc6aecda6a148776c0f5
# pangolin                  0x60781c2586d68229fde47564546784ab3faca982
# avalaunch                 0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
#
#                          blockchain
# benqi-liquid-staked-avax  avalanche
# joe                       avalanche
# benqi                     avalanche
# pangolin                  avalanche
# avalaunch                      None

# %% [markdown]
# ## Contract Output

# %%
methodology_class.output_for_contract()
# Out:
# 0x2b2c81e08f1af8835a78bb2a90ae924ace0ea4be,0x60781c2586d68229fde47564546784ab3faca982,0x6e84a6216ea6dacc71ee8e6b0a5b7322eebc0fdd,0x8729438eb15e2c8b576fcc6aecda6a148776c0f5,0xd1c3f94de7e5b45fa4edbba472491a9f4b166fc4
# 128,26,66,35,0
