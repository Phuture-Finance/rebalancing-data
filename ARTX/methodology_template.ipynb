# %% [markdown]
# ## PL2 - Phuture Layer 2 Index - Methodology Template

# %% [markdown]
# ## Configuring packages

# %%
import pandas as pd
import decouple
import sys
sys.path.append('../')
from methodology import MethodologyBase
from pycoingecko import CoinGeckoAPI
key =  decouple.config("CG_KEY")
cg = CoinGeckoAPI(api_key=key)

# %% [markdown]
# ## Index Variables

# %%
min_mcap =  0
min_weight = 0
max_weight = 0
circ_supply_threshold = 0
liveness_threshold = 1 # In days
liquidity_consistency = 90 # In days

methodology_class = MethodologyBase(
                                'arbitrum-one',
                                min_mcap,
                                min_weight,
                                max_weight,
                                65535,
                                circ_supply_threshold,
                                liveness_threshold,
                                liquidity_consistency,
                                -0.01,
                                10000)

# %% [markdown]
# ### Token inclusion criteria
#
# 1. **Project and token characteristics**
#     1. The project’s token should have been listed on CoinGecko with pricing data spanning at least 6 months prior to the date of inclusion in the index.
#     1. The project should have an active community.
#     1. No rebasing or deflationary tokens.
#     1. Synthetic tokens which derive their value from external price feeds are not permissible.
#     1. The project’s token must not have the ability to pause token transfers.
#     1. The project must have a minimum circulating market cap of $50mm.
#    <br>
# 1. **Pricing requirmeents**
#     1. Token should have a reliable price feed from one of our authorised providers.
#     <br>
# 1. **Token Supply requirements**
#     1. The project's token must have a circulating supply greater than 20% of the max supply. In cases where a token does not have a max supply, the minting mechanics would need to be assessed.
#     <br>
# 1. **Liquidity Requirements**
#     1. The token must be listed on a supported exchange.
#     1. The price should experience no more than 12% price impact when executing a $100k trade.
#     <br>
# 1. **Security Requirements**
#     1. The project must have been audited by smart contract security professionals with the audit report(s) publicly available. Alternatively, the protocol must have been operating long enough to create a consensus about its safety in the decentralised finance community.
# 1. **Weighting requirements**
#     1. The maximum weight any one token can have is 30%.
#     1. All excess weight is proportionally redistributed to all uncapped tokens. After this has been completed, if another token now exceeds the 30% threshold the excess will be redistributed to the remaining uncapped tokens. This process will occur iteratively until there are no tokens that exceed the maximum weight.
#     1. Any asset with a weight below 0.5% will be removed from the index.

# %% [markdown]
# ## Run Methodology

# %%
methodology_class.add_assets_to_category([
    'wrapped-bitcoin',
    'weth',
    'frax-share',
    'aave',
    'wrapped-tron',
    'premia',
    'mantle',
    'wrapped-telos',
    'celestia',
    'arbitrum',
    'optimism',
    'avalanche-2',
    'cosmos',
    'wrapped-solana',
    'uniswap',
    'chainlink',
    'curve-dao-token',
    'maker',
    'apecoin',
    'convex-finance',
    'manta-network',
    'reserve-rights-token',
    'the-open-network'
    ])
methodology_class.get_all_coin_data()
methodology_class.filter_and_merge_coin_data()
methodology_class.add_platform_to_token([{"id":"wrapped-solana","blockchain":'polygon-pos',"address":"0xd93f7e271cb87c23aaa73edc008a79646d1f9912"}])
methodology_class.category_data
# Out:
#                       symbol             name  current_price    market_cap  \
# id
# the-open-network         TON          Toncoin       6.080000  2.111273e+10
# avalanche-2             AVAX        Avalanche      33.820000  1.278366e+10
# wrapped-bitcoin         WBTC  Wrapped Bitcoin   61526.000000  9.537634e+09
# chainlink               LINK        Chainlink      13.200000  7.750407e+09
# uniswap                  UNI          Uniswap       6.920000  5.229164e+09
# mantle                   MNT           Mantle       1.150000  3.764971e+09
# cosmos                  ATOM       Cosmos Hub       8.070000  3.154169e+09
# arbitrum                 ARB         Arbitrum       1.110000  2.932440e+09
# maker                    MKR            Maker    3173.780000  2.931643e+09
# optimism                  OP         Optimism       2.170000  2.274059e+09
# aave                    AAVE             Aave      84.580000  1.252137e+09
# apecoin                  APE          ApeCoin       1.200000  7.509603e+08
# curve-dao-token          CRV        Curve DAO       0.428834  5.102501e+08
# frax-share               FXS       Frax Share       4.840000  3.822866e+08
# reserve-rights-token     RSR   Reserve Rights       0.005763  2.918264e+08
# convex-finance           CVX   Convex Finance       2.570000  2.105547e+08
# premia                PREMIA           Premia       0.299798  1.169647e+07
# weth                    WETH             WETH    2996.880000  0.000000e+00
# wrapped-solana           SOL   Wrapped Solana     132.270000  0.000000e+00
# wrapped-telos          WTLOS    Wrapped Telos       0.291393  0.000000e+00
# wrapped-tron            WTRX     Wrapped Tron       0.109198  0.000000e+00
#
#                       market_cap_rank  fully_diluted_valuation  \
# id
# the-open-network                 10.0             3.105343e+10
# avalanche-2                      13.0             1.476859e+10
# wrapped-bitcoin                  15.0             9.537634e+09
# chainlink                        18.0             1.320117e+10
# uniswap                          24.0             6.937377e+09
# mantle                           27.0             7.172909e+09
# cosmos                           34.0             3.156120e+09
# arbitrum                         38.0             1.104938e+10
# maker                            39.0             3.099396e+09
# optimism                         48.0             9.343023e+09
# aave                             75.0             1.353356e+09
# apecoin                         112.0             1.196100e+09
# curve-dao-token                 154.0             9.044580e+08
# frax-share                      191.0             4.827807e+08
# reserve-rights-token            223.0             5.767320e+08
# convex-finance                  271.0             2.556056e+08
# premia                         1319.0             3.005234e+07
# weth                              NaN             9.219051e+09
# wrapped-solana                    NaN                      NaN
# wrapped-telos                     NaN                      NaN
# wrapped-tron                      NaN                      NaN
#
#                       circulating_supply  total_supply  \
# id
# the-open-network            3.471060e+09  5.105371e+09
# avalanche-2                 3.779806e+08  4.366702e+08
# wrapped-bitcoin             1.552328e+05  1.552328e+05
# chainlink                   5.871000e+08  1.000000e+09
# uniswap                     7.537667e+08  1.000000e+09
# mantle                      3.264442e+09  6.219317e+09
# cosmos                      3.906884e+08  3.909300e+08
# arbitrum                    2.653939e+09  1.000000e+10
# maker                       9.247173e+05  9.776310e+05
# optimism                    1.045380e+09  4.294967e+09
# aave                        1.480333e+07  1.600000e+07
# apecoin                     6.278409e+08  1.000000e+09
# curve-dao-token             1.187548e+09  2.105022e+09
# frax-share                  7.893211e+07  9.968150e+07
# reserve-rights-token        5.060000e+10  1.000000e+11
# convex-finance              8.199070e+07  9.953367e+07
# premia                      3.892033e+07  1.000000e+08
# weth                        0.000000e+00  3.075796e+06
# wrapped-solana              0.000000e+00           NaN
# wrapped-telos               0.000000e+00           NaN
# wrapped-tron                0.000000e+00           NaN
#
#                                                               platforms
# id
# the-open-network      {'ethereum': '0x582d872a1b094fc48f5de31d3b73f2...
# avalanche-2                                                          {}
# wrapped-bitcoin       {'ethereum': '0x2260fac5e5542a773aa44fbcfedf7c...
# chainlink             {'ethereum': '0x514910771af9ca656af840dff83e82...
# uniswap               {'ethereum': '0x1f9840a85d5af5bf1d1762f925bdad...
# mantle                {'ethereum': '0x3c3a81e81dc49a522a592e7622a7e7...
# cosmos                {'cosmos': 'uatom', 'kava': '0x15932e26f5bd492...
# arbitrum              {'arbitrum-one': '0x912ce59144191c1204e64559fe...
# maker                 {'ethereum': '0x9f8f72aa9304c8b593d555f12ef658...
# optimism              {'optimistic-ethereum': '0x4200000000000000000...
# aave                  {'ethereum': '0x7fc66500c84a76ad7e9c93437bfc5a...
# apecoin               {'ethereum': '0x4d224452801aced8b2f0aebe155379...
# curve-dao-token       {'ethereum': '0xd533a949740bb3306d119cc777fa90...
# frax-share            {'ethereum': '0x3432b6a60d23ca0dfca7761b7ab564...
# reserve-rights-token  {'ethereum': '0x320623b8e4ff03373931769a31fc52...
# convex-finance        {'ethereum': '0x4e3fbd56cd56c3e72c1403e103b45d...
# premia                {'ethereum': '0x6399c842dd2be3de30bf99bc7d1bbf...
# weth                  {'ethereum': '0xc02aaa39b223fe8d0a0e5c4f27ead9...
# wrapped-solana        {'solana': 'So11111111111111111111111111111111...
# wrapped-telos         {'telos': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# wrapped-tron          {'tron': 'TNUC9Qb1rRpS5CbWLmNMxXBjyFoydXjWFR',...

# %%
a,b = methodology_class.assess_liquidity(['ethereum'])
a
# Out:
# polygon-zkevm not supported
# sora not supported
# cronos not supported
# zksync not supported
# energi not supported
# tomochain not supported
# harmony-shard-0 not supported
# moonriver not supported
# boba not supported
# metis-andromeda not supported
# xdai not supported
# aurora not supported
# fuse not supported
# meter not supported
# moonbeam not supported
# telos not supported
# syscoin not supported
# milkomeda-cardano not supported
# conflux not supported
# kava not supported
# astar not supported
# cube not supported
# velas not supported
# klay-token not supported
# hydra not supported
# step-network not supported
# near-protocol not supported
# celo not supported
# thundercore not supported
# energi not supported
# near-protocol not supported
# huobi-token not supported
# xdai not supported
# harmony-shard-0 not supported
# sora not supported
# milkomeda-cardano not supported
# osmosis not supported
# xdai not supported
# Manually calculating slippage for uniswap on avalanche
# near-protocol not supported
# energi not supported
# huobi-token not supported
# harmony-shard-0 not supported
# sora not supported
# mantle not supported
# cosmos not supported
# kava not supported
# evmos not supported
# archway not supported
# osmosis not supported
# canto not supported
# arbitrum-nova not supported
# energi not supported
# sora not supported
# sora not supported
# near-protocol not supported
# huobi-token not supported
# harmony-shard-0 not supported
# energi not supported
# energi not supported
# sora not supported
# polygon-zkevm not supported
# moonriver not supported
# harmony-shard-0 not supported
# evmos not supported
# solana not supported
# energi not supported
# Manually calculating slippage for premia on optimistic-ethereum
# thundercore not supported
# zksync not supported
# callisto not supported
# polygon-zkevm not supported
# sora not supported
# blast not supported
# cronos not supported
# energi not supported
# kardiachain not supported
# conflux not supported
# xdai not supported
# harmony-shard-0 not supported
# moonbeam not supported
# ronin not supported
# boba not supported
# tron not supported
# aurora not supported
# metis-andromeda not supported
# moonriver not supported
# tomochain not supported
# kucoin-community-chain not supported
# meter not supported
# theta not supported
# telos not supported
# syscoin not supported
# milkomeda-cardano not supported
# elastos not supported
# celo not supported
# cosmos not supported
# kava not supported
# sx-network not supported
# astar not supported
# cube not supported
# arbitrum-nova not supported
# canto not supported
# dogechain not supported
# klay-token not supported
# near-protocol not supported
# velas not supported
# astar-zkevm not supported
# mode not supported
# solana not supported
# neon-evm not supported
# energi not supported
# near-protocol not supported
# telos not supported
# tron not supported
# energi not supported
# bittorrent not supported
# /Users/olivermehr/Documents/GitHub/rebalancing-data/ARTX/../methodology.py:445: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   slippages["best slippage chain"] = slippages.idxmax(
#                 symbol             name  current_price    market_cap  \
# id
# avalanche-2       AVAX        Avalanche          33.82  1.278366e+10
# wrapped-bitcoin   WBTC  Wrapped Bitcoin       61526.00  9.537634e+09
# chainlink         LINK        Chainlink          13.20  7.750407e+09
# uniswap            UNI          Uniswap           6.92  5.229164e+09
# arbitrum           ARB         Arbitrum           1.11  2.932440e+09
# optimism            OP         Optimism           2.17  2.274059e+09
# aave              AAVE             Aave          84.58  1.252137e+09
# weth              WETH             WETH        2996.88  0.000000e+00
# wrapped-solana     SOL   Wrapped Solana         132.27  0.000000e+00
#
#                  market_cap_rank  fully_diluted_valuation  circulating_supply  \
# id
# avalanche-2                 13.0             1.476859e+10        3.779806e+08
# wrapped-bitcoin             15.0             9.537634e+09        1.552328e+05
# chainlink                   18.0             1.320117e+10        5.871000e+08
# uniswap                     24.0             6.937377e+09        7.537667e+08
# arbitrum                    38.0             1.104938e+10        2.653939e+09
# optimism                    48.0             9.343023e+09        1.045380e+09
# aave                        75.0             1.353356e+09        1.480333e+07
# weth                         NaN             9.219051e+09        0.000000e+00
# wrapped-solana               NaN                      NaN        0.000000e+00
#
#                  total_supply  \
# id
# avalanche-2      4.366702e+08
# wrapped-bitcoin  1.552328e+05
# chainlink        1.000000e+09
# uniswap          1.000000e+09
# arbitrum         1.000000e+10
# optimism         4.294967e+09
# aave             1.600000e+07
# weth             3.075796e+06
# wrapped-solana            NaN
#
#                                                          platforms
# id
# avalanche-2                                                     {}
# wrapped-bitcoin  {'ethereum': '0x2260fac5e5542a773aa44fbcfedf7c...
# chainlink        {'ethereum': '0x514910771af9ca656af840dff83e82...
# uniswap          {'ethereum': '0x1f9840a85d5af5bf1d1762f925bdad...
# arbitrum         {'arbitrum-one': '0x912ce59144191c1204e64559fe...
# optimism         {'optimistic-ethereum': '0x4200000000000000000...
# aave             {'ethereum': '0x7fc66500c84a76ad7e9c93437bfc5a...
# weth             {'ethereum': '0xc02aaa39b223fe8d0a0e5c4f27ead9...
# wrapped-solana   {'solana': 'So11111111111111111111111111111111...

# %%
b
# Out:
#                       arbitrum-one  avalanche      base  binance-smart-chain  \
# id
# arbitrum                 -0.000998        NaN       NaN                  NaN
# wrapped-bitcoin          -0.001068  -0.004673       NaN                  NaN
# weth                     -0.001071  -0.003898 -0.001092            -0.001543
# avalanche-2                    NaN  -0.002959       NaN                  NaN
# chainlink                -0.005718  -0.079960       NaN            -0.011560
# optimism                       NaN        NaN       NaN                  NaN
# wrapped-solana                 NaN        NaN       NaN            -0.006202
# aave                           NaN  -0.861103       NaN            -0.047198
# uniswap                  -0.008960  -0.971454       NaN            -0.017791
# curve-dao-token          -0.028425        NaN       NaN                  NaN
# wrapped-telos                  NaN        NaN       NaN            -0.021493
# premia                   -0.027012        NaN       NaN                  NaN
# cosmos                         NaN        NaN       NaN            -0.052750
# maker                          NaN  -0.999925       NaN                  NaN
# apecoin                        NaN        NaN       NaN                  NaN
# frax-share               -0.715554  -0.973632       NaN            -0.784753
# reserve-rights-token           NaN        NaN -0.770458                  NaN
# the-open-network               NaN        NaN       NaN            -1.000000
# mantle                         NaN        NaN       NaN                  NaN
# convex-finance                 NaN        NaN       NaN                  NaN
# wrapped-tron                   NaN        NaN       NaN                  NaN
#
#                         fantom  optimistic-ethereum  polygon-pos  \
# id
# arbitrum                   NaN                  NaN          NaN
# wrapped-bitcoin      -1.000000            -1.000000    -0.002561
# weth                 -0.015437            -0.001413    -0.001169
# avalanche-2                NaN                  NaN          NaN
# chainlink            -0.029575            -0.016535    -0.003370
# optimism                   NaN            -0.003759          NaN
# wrapped-solana       -0.395680                  NaN    -0.019434
# aave                 -0.230340            -0.454169    -0.007794
# uniswap                    NaN            -0.464856    -0.013733
# curve-dao-token      -0.044096            -0.651539    -0.015061
# wrapped-telos              NaN                  NaN          NaN
# premia               -0.424982            -1.000000          NaN
# cosmos                     NaN                  NaN          NaN
# maker                      NaN                  NaN    -0.111340
# apecoin                    NaN                  NaN    -0.191822
# frax-share           -0.999116                  NaN    -0.745131
# reserve-rights-token       NaN                  NaN          NaN
# the-open-network           NaN                  NaN          NaN
# mantle                     NaN                  NaN          NaN
# convex-finance             NaN                  NaN          NaN
# wrapped-tron               NaN                  NaN          NaN
#
#                             optimal chain  best slippage  best slippage chain
# id
# arbitrum                     arbitrum-one      -0.000998         arbitrum-one
# wrapped-bitcoin              arbitrum-one      -0.001068         arbitrum-one
# weth                         arbitrum-one      -0.001071         arbitrum-one
# avalanche-2                     avalanche      -0.002959            avalanche
# chainlink                    arbitrum-one      -0.003370          polygon-pos
# optimism              optimistic-ethereum      -0.003759  optimistic-ethereum
# wrapped-solana        binance-smart-chain      -0.006202  binance-smart-chain
# aave                          polygon-pos      -0.007794          polygon-pos
# uniswap                      arbitrum-one      -0.008960         arbitrum-one
# curve-dao-token                      None      -0.015061          polygon-pos
# wrapped-telos                        None      -0.021493  binance-smart-chain
# premia                               None      -0.027012         arbitrum-one
# cosmos                               None      -0.052750  binance-smart-chain
# maker                                None      -0.111340          polygon-pos
# apecoin                              None      -0.191822          polygon-pos
# frax-share                           None      -0.715554         arbitrum-one
# reserve-rights-token                 None      -0.770458                 base
# the-open-network                     None      -1.000000  binance-smart-chain
# mantle                               None            NaN                  NaN
# convex-finance                       None            NaN                  NaN
# wrapped-tron                         None            NaN                  NaN
